# %% [markdown]
# # Style Transfer by Relaxed Optimal Transport and Self-Similarity + Auto mask pyramid
#
# import the module we need

# %%
import torch
import torchvision
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F
import torch.optim as optim
import torchvision.models as models
import torchvision.transforms as transforms
from imageio import imread
import numpy as np
import os
import math
import PIL
from time import time
from Patch_Match import PatchMatch
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

patch_match_feat_layer=29
AUTO_MASK_PYRAMID=False

print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
if torch.cuda.is_available():
  print("Using the GPU!")
elif torch.backends.mps.is_available():
  print("Using the MPS!")
else:
  print("WARNING: Could not find GPU! Using CPU only. If you want to enable GPU, please to go Edit > Notebook Settings > Hardware Accelerator and select GPU.")
# Out:
# PyTorch Version:  2.2.0+cu118
# Torchvision Version:  0.17.0+cu118
# Using the GPU!

# %% [markdown]
# ## Step 1: helper functions

# %% [markdown]
# ### Tensor and PIL utils

# %%
use_random=True

# load PIL image
def pil_loader(path):
    with open(path, 'rb') as f:
        img = PIL.Image.open(f)
        return img.convert('RGB')
# tensor插值
def tensor_resample(tensor, dst_size, mode='bilinear'):
    return F.interpolate(tensor, dst_size, mode=mode, align_corners=False)
# image resize by short edge
def pil_resize_short_edge_to(pil, trg_size):
    short_w = pil.width < pil.height
    ar_resized_short = (trg_size / pil.width) if short_w else (trg_size / pil.height)
    resized = pil.resize((int(pil.width * ar_resized_short), int(pil.height * ar_resized_short)), PIL.Image.BICUBIC)
    return resized
# image resize by long edge
def pil_resize_long_edge_to(pil, trg_size):
    short_w = pil.width < pil.height
    ar_resized_long = (trg_size / pil.height) if short_w else (trg_size / pil.width)
    resized = pil.resize((int(pil.width * ar_resized_long), int(pil.height * ar_resized_long)), PIL.Image.BICUBIC)
    return resized

def np_to_pil(npy):
    return PIL.Image.fromarray(npy.astype(np.uint8))

def pil_to_np(pil):
    return np.array(pil)

# %%
def tensor_to_np(tensor, cut_dim_to_3=True):
    if len(tensor.shape) == 4:
        if cut_dim_to_3:
            tensor = tensor[0]
        else:
            return tensor.detach().cpu().numpy().transpose((0, 2, 3, 1))
    return tensor.detach().data.cpu().numpy().transpose((1,2,0))

def np_to_tensor(npy, space):
    if space == 'vgg':
        return np_to_tensor_correct(npy)
    return (torch.Tensor(npy.astype(np.float64) / 127.5) - 1.0).permute((2,0,1)).unsqueeze(0)

def np_to_tensor_correct(npy):
    pil = np_to_pil(npy)
    transform = transforms.Compose([transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    return transform(pil).unsqueeze(0)

# %% [markdown]
# ### Laplacian Pyramid

# %%
def laplacian(x):
    # x - upsample(downsample(x))
    return x - tensor_resample(tensor_resample(x, [x.shape[2] // 2, x.shape[3] // 2]), [x.shape[2], x.shape[3]])

def make_laplace_pyramid(x, levels):
    pyramid = []
    current = x
    for i in range(levels):
        pyramid.append(laplacian(current))
        current = tensor_resample(current, (max(current.shape[2] // 2,1), max(current.shape[3] // 2,1)))
    pyramid.append(current)
    return pyramid

def fold_laplace_pyramid(pyramid):
    current = pyramid[-1]
    for i in range(len(pyramid)-2, -1, -1): # iterate from len-2 to 0
        up_h, up_w = pyramid[i].shape[2], pyramid[i].shape[3]
        current = pyramid[i] + tensor_resample(current, (up_h,up_w))
    return current

# %% [markdown]
# ### Feature sampling

# %%
def sample_indices(feat_content, feat_style_all, r, ri, xx, xy, yx):

    indices = None
    const = 128**2 # 32k or so

    feat_style =  feat_style_all[ri]

    for i in range(len(feat_style)):
        
        feat_cont = feat_content[i]
        d = feat_style[i].size(1)
        feat_style_st = feat_style[i].view(1,d,-1,1)
        big_size = feat_cont.shape[2] * feat_cont.shape[3] # num feaxels

        stride_x = int(max(math.floor(math.sqrt(big_size//const)),1))
        offset_x = np.random.randint(stride_x)
        stride_y = int(max(math.ceil(math.sqrt(big_size//const)),1))
        offset_y = np.random.randint(stride_y)
        xx_arr, xy_arr = np.meshgrid(np.arange(feat_cont.shape[2])[offset_x::stride_x], np.arange(feat_cont.shape[3])[offset_y::stride_y])

        xx_arr = np.expand_dims(xx_arr.flatten(),1)
        xy_arr = np.expand_dims(xy_arr.flatten(),1)
        xc = np.concatenate([xx_arr,xy_arr], 1)

        region_mask = r

        try:
            xc = xc[region_mask[xy_arr[:,0],xx_arr[:,0]], :]
        except:
            region_mask = region_mask[:,:]
            xc = xc[region_mask[xy_arr[:,0],xx_arr[:,0]], :]
        
        xx[ri].append(xc[:,0])
        xy[ri].append(xc[:,1])

        feat_result = np.arange(feat_style_st.size(2)).astype(np.int32)
        yx[ri].append(feat_result)

def get_feature_indices(xx_dict, xy_dict, yx_dict, ri=0, i=0, cnt=32**2):

    xx = xx_dict[ri][i][:cnt]
    xy = xy_dict[ri][i][:cnt]
    yx = yx_dict[ri][i][:cnt]

    return xx, xy, yx

# %% [markdown]
# ### Extract spatial features from VGG layers

# %%
def spatial_feature_extract(feat_result, feat_content, xx, xy):

    l2, l3 = [], []
    device = feat_result[0].device

    # for each extracted layer
    for i in range(len(feat_result)):
        fr = feat_result[i]
        fc = feat_content[i]

        # hack to detect reduced scale
        if i>0 and feat_result[i-1].size(2) > feat_result[i].size(2):
            xx = xx/2.0
            xy = xy/2.0


        # go back to ints and get residual
        xxm = np.floor(xx).astype(np.float32)
        xxr = xx - xxm

        xym = np.floor(xy).astype(np.float32)
        xyr = xy - xym

        # do bilinear resample
        w00 = torch.from_numpy((1.-xxr)*(1.-xyr)).float().view(1, 1, -1, 1).to(device)
        w01 = torch.from_numpy((1.-xxr)*xyr).float().view(1, 1, -1, 1).to(device)
        w10 = torch.from_numpy(xxr*(1.-xyr)).float().view(1, 1, -1, 1).to(device)
        w11 = torch.from_numpy(xxr*xyr).float().view(1, 1, -1, 1).to(device)

        xxm = np.clip(xxm.astype(np.int32),0,fr.size(2)-1)
        xym = np.clip(xym.astype(np.int32),0,fr.size(3)-1)

        s00 = xxm*fr.size(3)+xym
        s01 = xxm*fr.size(3)+np.clip(xym+1,0,fr.size(3)-1)
        s10 = np.clip(xxm+1,0,fr.size(2)-1)*fr.size(3)+(xym)
        s11 = np.clip(xxm+1,0,fr.size(2)-1)*fr.size(3)+np.clip(xym+1,0,fr.size(3)-1)

        fr = fr.view(1,fr.size(1),fr.size(2)*fr.size(3),1)
        fr = fr[:,:,s00,:].mul_(w00).add_(fr[:,:,s01,:].mul_(w01)).add_(fr[:,:,s10,:].mul_(w10)).add_(fr[:,:,s11,:].mul_(w11))

        fc = fc.view(1,fc.size(1),fc.size(2)*fc.size(3),1)
        fc = fc[:,:,s00,:].mul_(w00).add_(fc[:,:,s01,:].mul_(w01)).add_(fc[:,:,s10,:].mul_(w10)).add_(fc[:,:,s11,:].mul_(w11))

        l2.append(fr)
        l3.append(fc)

    x_st = torch.cat([li.contiguous() for li in l2],1)
    c_st = torch.cat([li.contiguous() for li in l3],1)

    xx = torch.from_numpy(xx).view(1,1,x_st.size(2),1).float().to(device)
    yy = torch.from_numpy(xy).view(1,1,x_st.size(2),1).float().to(device)
    
    x_st = torch.cat([x_st,xx,yy],1)
    c_st = torch.cat([c_st,xx,yy],1)
    return x_st, c_st

# %% [markdown]
# ### Color and distance helper functions

# %%
def rgb_to_yuv(rgb):
    C = torch.Tensor([[0.577350,0.577350,0.577350],[-0.577350,0.788675,-0.211325],[-0.577350,-0.211325,0.788675]]).to(rgb.device)
    yuv = torch.mm(C,rgb)
    return yuv

def pairwise_distances_cos(x, y):
    x_norm = torch.sqrt((x**2).sum(1).view(-1, 1))
    y_t = torch.transpose(y, 0, 1)
    y_norm = torch.sqrt((y**2).sum(1).view(1, -1))
    dist = 1.-torch.mm(x, y_t)/x_norm/y_norm
    return dist

def pairwise_distances_sq_l2(x, y):
    x_norm = (x**2).sum(1).view(-1, 1)
    y_t = torch.transpose(y, 0, 1)
    y_norm = (y**2).sum(1).view(1, -1)
    dist = x_norm + y_norm - 2.0 * torch.mm(x, y_t)
    return torch.clamp(dist, 1e-5, 1e5)/x.size(1)

# %% [markdown]
# ### Create mask by ignoring some color

# %%
def create_mask_from_image(image, ignore_color=[0, 0, 0]):
    """
    Create a mask from an image, where pixels matching the ignore_color are set to 0, and others to 1.

    :param image: input image.
    :param ignore_color: Color to be ignored, default is black ([0, 0, 0]).
    :return: Mask tensor of shape (1, H, W), where 1 indicates important areas and 0 indicates areas to ignore.
    """

    # Check if the image is grayscale or RGB
    if len(image.shape) == 2:  # Grayscale image
        mask = image != ignore_color[0]
    else:  # RGB image
        mask = np.all(image != ignore_color, axis=-1)

    mask = torch.from_numpy(mask).unsqueeze(0).float()

    return mask

# %% [markdown]
# ### Regions building functions

# %%
def extract_color_regions(content_path, style_path):
    s_regions = imread(style_path).transpose(1,0,2)
    c_regions = imread(content_path).transpose(1,0,2)

    color_codes,c1 = np.unique(s_regions.reshape(-1, s_regions.shape[2]), axis=0,return_counts=True)
    
    color_codes = color_codes[c1>10000]

    c_out = []
    s_out = []

    for c in color_codes:
        c_expand =  np.expand_dims(np.expand_dims(c,0),0)
        
        s_mask = np.equal(np.sum(s_regions - c_expand,axis=2),0).astype(np.float32)
        c_mask = np.equal(np.sum(c_regions - c_expand,axis=2),0).astype(np.float32)

        s_out.append(s_mask)
        c_out.append(c_mask)
    return [c_out,s_out]

# %%
def build_from_matches(matches,num_of_maxpool,img1,img2):
    # 首先我们要找到feat11、feat22中每一个坐标分别对应了其原图中的感受野是那一片
    # 然后regions是我们要返回的区域对应关系
    # regions是若干对mask的list，其中每一对mask标出了feat11一个元素对应的原图中感受野，另一个mask标出了feat22一个元素对应的原图中感受野
    # 首先要找出对应了相同的x,y的点，然后根据这些点找出对应的感受野
    dict={}
    for i in range(matches.shape[0]):
        for j in range(matches.shape[1]):
            x1,y1=i,j
            x2,y2=matches[i,j]
            if (x2,y2) not in dict:
                dict[(x2,y2)]=[]
            dict[(x2,y2)].append((x1,y1))
    # 设置权重
    weight2 = 3  # 图像 2 中点的权重
    weight1 = 1  # 图像 1 中点的权重
    
    # 提取点对
    point_pairs = []
    for i in range(matches.shape[0]):
        for j in range(matches.shape[1]):
            img1_point = [i*weight1, j*weight1]  # 图像1的坐标
            img2_point = matches[i, j]  # 图像2的坐标
            point_pairs.append(img1_point +[x*weight2 for x in  list(img2_point)])
    point_pairs = np.array(point_pairs)
    # 选择聚类类别数范围
    range_n_clusters = range(3, min(11,len(point_pairs)))
    scores = []
    best_n_clusters = None
    best_score = -1
    best_labels = None

    # 自动选择最佳类别数
    for n_clusters in range_n_clusters:
        kmeans = KMeans(n_clusters=n_clusters, random_state=0)
        labels = kmeans.fit_predict(point_pairs)
        score = silhouette_score(point_pairs, labels)
        scores.append(score)
        
        if score > best_score:
            best_score = score
            best_n_clusters = n_clusters
            best_labels = labels

    # 聚类结果分组
    clusters = [[] for _ in range(best_n_clusters)]
    for idx, label in enumerate(best_labels):
        img1_coords = point_pairs[idx][:2]  # 图像1坐标
        img2_coords = point_pairs[idx][2:]  # 图像2坐标
        clusters[label].append((img1_coords, img2_coords))
    
    # 分离图像1和图像2中的点
    result = []
    for cluster in clusters:
        img1_points = [pair[0] for pair in cluster]
        img2_points = [pair[1] for pair in cluster]
        result.append([img1_points, img2_points])
    print(f"最佳类别数：{best_n_clusters}, 轮廓系数：{best_score:.4f}")
    c_out,s_out=[],[]
    l=2**num_of_maxpool+2 # 18
    for points in result:
        mask1=np.zeros(img1.size)
        mask2=np.zeros(img2.size)
        for x1,y1 in points[0]:
            mask1[x1*l:min((x1+1)*l,img1.size[0]),y1*l:min((y1+1)*l,img1.size[1])]=1
        for x2,y2 in points[1]:
            mask2[x2*l:min((x2+1)*l,img2.size[0]),y2*l:min((y2+1)*l,img2.size[1])]=1
        c_out.append(mask1)
        s_out.append(mask2)
    return [c_out,s_out]

# %% [markdown]
# ### Compute distance of two vectors

# %%
def distmat(x, y, cos_d=True):
    if cos_d:
        M = pairwise_distances_cos(x, y)
    else:
        M = torch.sqrt(pairwise_distances_sq_l2(x, y))
    return M

# %% [markdown]
# ## Step 2: Loss functions

# %% [markdown]
# ### Content loss function
#
# Formal Definition: Let  $D^{X}$  be the pairwise cosine distance matrix of all feature vectors extracted from  $X^{(t)}$ , and let  $D^{I_{C}}$  represent the corresponding matrix for the content image.
#
# The content loss is defined as:
# $\mathcal{L}_{\text{content}}(X, C) = \frac{1}{n^2} \sum{i,j} \left| \frac{D_{ij}^{X}}{\sum_i D_{ij}^{X}} - \frac{D_{ij}^{I_{C}}}{\sum_i D_{ij}^{I_{C}}} \right|$
#
# Interpretation of this loss: For the normalized cosine distances between feature vectors (row-wise normalization), the values should remain consistent between the content image and the output image.
#
# Effect of this loss: This loss preserves the structure of the output image without enforcing direct pixel-wise similarity to the content image. As a result, the semantics and local layout of the content are maintained, while allowing the pixel values in  $X^{(t)}$  to differ significantly from those in the content image.

# %%
def content_loss(feat_result, feat_content):
    d = feat_result.size(1)

    X = feat_result.transpose(0,1).contiguous().view(d,-1).transpose(0,1)
    Y = feat_content.transpose(0,1).contiguous().view(d,-1).transpose(0,1)

    Y = Y[:,:-2]
    X = X[:,:-2]
    # X = X.t()
    # Y = Y.t()

    Mx = distmat(X, X)
    Mx = Mx#/Mx.sum(0, keepdim=True)

    My = distmat(Y, Y)
    My = My#/My.sum(0, keepdim=True)

    d = torch.abs(Mx-My).mean()# * X.shape[0]
    return d

# %% [markdown]
# ### Style loss functions
#
# Let  $A = \{ A_1, \dots, A_n \}$  represent a set of  n  feature vectors extracted from  $X^{(t)}$ , and  $B = \{ B_1, \dots, B_m \}$  represent a set of  m  feature vectors extracted from the style image  $I_S$ . The style loss is derived from the Earth Mover’s Distance (EMD):
#
#
# $$EMD(A, B) = \min_{T \geq 0} \sum_{i,j} T_{ij} C_{ij}$$
#
# - Constraints on  T :$$\sum_j T_{ij} = \frac{1}{m}, \quad \sum_i T_{ij} = \frac{1}{n}$$
#   - T  is the transport matrix, where  $T_{ij}$  represents the weight of the distance between the  i -th element of  A  and the  j -th element of  B  in the EMD computation.
#   - $T_{ij}$  is non-negative and is optimized during the computation.
#
#
# - Cost Matrix  C :
#   - $C_{ij}$  represents the distance between the  i -th element of  A  and the  j -th element of  B .
#
# The EMD measures the distance between two sets. However, computing the optimal  T  has a time complexity of  $O(\max(n, m)^3)$ , which is computationally impractical for gradient-based style transfer.
#
# Relaxed EMD:
#
# To address this, a relaxed version of the EMD is used. Two auxiliary distances are defined by considering only one of the original constraints at a time:
#
# 1.	Relaxed EMD for  A :
#
# $$R_A(A, B) = \min_{T \geq 0} \sum_{i,j} T_{ij} C_{ij}, \quad \text{s.t.} \quad \sum_j T_{ij} = \frac{1}{m}$$
#
# 2.	Relaxed EMD for  B :
#
# $$R_B(A, B) = \min_{T \geq 0} \sum_{i,j} T_{ij} C_{ij}, \quad \text{s.t.} \quad \sum_i T_{ij} = \frac{1}{n}$$
#
#
# The relaxed EMD is then defined as:
#
# $$l_r = REMD(A, B) = \max(R_A(A, B), R_B(A, B))$$
#
#
# This can be equivalently expressed as:
#
# $$l_r = \max\left( \frac{1}{n} \sum_j \min_i C_{ij}, \frac{1}{m} \sum_i \min_j C_{ij} \right)$$

# %%
def style_loss(X, Y, cos_d=True):
    d = X.shape[1]

    if d == 3:
        X = rgb_to_yuv(X.transpose(0,1).contiguous().view(d,-1)).transpose(0,1)
        Y = rgb_to_yuv(Y.transpose(0,1).contiguous().view(d,-1)).transpose(0,1)
    else:
        X = X.transpose(0,1).contiguous().view(d,-1).transpose(0,1)
        Y = Y.transpose(0,1).contiguous().view(d,-1).transpose(0,1)

    # Relaxed EMD
    CX_M = distmat(X, Y, cos_d=True)

    if d==3: CX_M = CX_M + distmat(X, Y, cos_d=False)

    m1, m1_inds = CX_M.min(1)
    m2, m2_inds = CX_M.min(0)

    remd = torch.max(m1.mean(), m2.mean())

    return remd

# %% [markdown]
# ### Moment loss function
#
# The relaxed EMD ( $l_r$ ) effectively transfers the structural style of the source image to the target image. However, cosine distance ( $D_{\cos}$ ) overlooks the magnitudes of feature vectors, leading to visual artifacts in the output, such as oversaturation or undersaturation of colors.
#
# To address this issue, a Moment Matching Loss is introduced. This loss improves the visual quality of the output, especially for color saturation and detail retention:
#
#
# $$l_m = \frac{1}{d} \| \mu_A - \mu_B \|_1 + \frac{1}{d^2} \| \Sigma_A - \Sigma_B \|_1$$
#
# - Components:
#   - $\mu_A$ : The mean of feature vectors in  A .
#   - $\Sigma_A$ : The covariance of feature vectors in  A .
#   - Similarly,  $\mu_B$  and  $\Sigma_B$  are the mean and covariance of feature vectors in  B .
#   - d : The dimensionality of the feature vectors.
# - Interpretation:
#   - The first term ( $\frac{1}{d} \| \mu_A - \mu_B \|_1$ ) ensures that the overall distributions of feature vector means for  A  and  B  are aligned.
#   - The second term ( $\frac{1}{d^2} \| \Sigma_A - \Sigma_B \|_1$ ) aligns the variances and correlations within the feature sets of  A  and  B .

# %%
def moment_loss(X, Y, moments=[1,2]):
    loss = 0.
    d = X.size(1)
    # X = X.squeeze().t()
    # Y = Y.squeeze().t()

    Xo = X.transpose(0,1).contiguous().view(d,-1).transpose(0,1)
    Yo = Y.transpose(0,1).contiguous().view(d,-1).transpose(0,1)

    splits = [Xo.size(1)]

    cb = 0
    ce = 0
    for i in range(len(splits)):
        ce = cb + splits[i]
        X = Xo[:,cb:ce]
        Y = Yo[:,cb:ce]
        cb = ce

        mu_x = torch.mean(X,0,keepdim=True)
        mu_y = torch.mean(Y,0,keepdim=True)
        mu_d = torch.abs(mu_x-mu_y).mean()

        if 1 in moments:
            # print(mu_x.shape)
            loss = loss + mu_d

        if 2 in moments:

            sig_x = torch.mm((X-mu_x).transpose(0,1), (X-mu_x))/X.size(0)
            sig_y = torch.mm((Y-mu_y).transpose(0,1), (Y-mu_y))/Y.size(0)

            sig_d = torch.abs(sig_x-sig_y).mean()

            # print(X_cov.shape)
            # exit(1)
            loss = loss + sig_d

    return loss

# %% [markdown]
# ### Calculating the loss
#
# This approach uses gradient descent with RMSprop to minimize the objective function based on the output image  X , given a style image ( $I_S$ ) and a content image ( $I_C$ ):
#
#
# $$L(X, I_C, I_S) = \frac{\alpha l_C + l_M + l_r + \frac{1}{\alpha} l_p}{2 + \alpha + \frac{1}{\alpha}}$$
#
# Components of the Objective Function:
# 1.	Content Term ( $\alpha l_C$ ):
#     - This term ensures that the output image  X  retains the structure and semantic layout of the content image  $I_C$ .
#     - Weighted by the hyperparameter  $\alpha$ , which controls the emphasis on preserving content.
# 2.	Style Terms ( $l_M + l_r + \frac{1}{\alpha} l_p$ ):
#     - Moment Matching Loss ( $l_M$ ): Helps align the color and detail distribution between  X  and the style image  $I_S$ , addressing issues like oversaturation.
#     - Relaxed EMD ( $l_r$ ): Ensures structural and style similarity by aligning the feature sets of  X  and  $I_S$ .
#     - Perceptual Loss ( $l_p$ ): A fine-grained loss term (scaled by  $\frac{1}{\alpha}$ ) to further refine the visual fidelity.

# %%
def calculate_loss(feat_result, feat_content, feat_style, xx_dict, xy_dict, yx_dict, content_weight, regions, moment_weight=1.0):
    # spatial feature extract
    num_locations = 1024
    loss_total = 0.

    for ri in range(len(regions[0])):
        xx, xy, yx = get_feature_indices(xx_dict, xy_dict, yx_dict, ri=ri, cnt=num_locations)
        spatial_result, spatial_content = spatial_feature_extract(feat_result, feat_content, xx, xy)

        loss_content = content_loss(spatial_result, spatial_content)

        d = feat_style[ri][0].shape[0]
        spatial_style = feat_style[ri][0].view(1, d, -1, 1)

        feat_max = 3+2*64+128*2+256*3+512*2 # (sum of all extracted channels)

        loss_remd = style_loss(spatial_result[:, :feat_max, :, :], spatial_style[:, :feat_max, :, :])

        loss_moment = moment_loss(spatial_result[:,:-2,:,:], spatial_style, moments=[1,2]) # -2 is so that it can fit?
        # palette matching
        content_weight_frac = 1./max(content_weight,1.)
        loss_moment += content_weight_frac * style_loss(spatial_result[:,:3,:,:], spatial_style[:,:3,:,:])
        
        loss_style = loss_remd + moment_weight * loss_moment
        print(f'Style: {loss_style.item():.3f}, Content: {loss_content.item():.3f}')

        style_weight = 1.0 + moment_weight
        loss_total += (content_weight * loss_content + loss_style) / (content_weight + style_weight)

    return loss_total/len(xx_dict.keys())

# %% [markdown]
# ## Step3: VGG network

# %% [markdown]
# ### Network design
#
# #### User Control in Style Transfer
# 1.	Integrating User Constraints
#     - User-defined constraints can restrict the output style by enforcing correspondence between two sets of local regions in  $X^{(t)}$  (output image) and  $I_S$  (style image).
#     - These regions are designed to have low style loss between the corresponding areas.
# 2.	Point-to-Point User Control
#     - Each correspondence involves a pair of single local points, defined as  $(X_{t_1}, S_{s_1}), \dots, (X_{t_K}, S_{s_K})$ .
#
# #### Redefining REMD with User Constraints
#
# The cost matrix  $C_{ij}$  in the Relaxed Earth Mover’s Distance (REMD) is redefined as:
#
#
# $$C_{ij} =
# \begin{cases}
# \beta \cdot D_{\cos}(A_i, B_j), & \text{if } i \in X_{t_k}, j \in S_{s_k} \\
# \infty, & \text{if } \exists k \text{ such that } i \in X_{t_k}, j \notin S_{s_k} \\
# D_{\cos}(A_i, B_j), & \text{otherwise}.
# \end{cases}$$
#
# - Explanation:
#   - $\beta$  controls the weight of user-specified constraints relative to unconstrained areas.
#   - In this study,  $\beta$  is set to 5 in all experiments.
#   - $D_{\cos}(A_i, B_j)$  represents the cosine distance between feature vectors  $A_i$  (output image) and  $B_j$  (style image).
#
# #### Enhancing Point-to-Point Control
#
# - To strengthen the constraints, for each originally defined point, a 3×3 grid of additional constraint points is created around it.
# - These new constraints include points within a 20-pixel horizontal and vertical distance of the original point in a 512×512 image.
# - The spacing can be adjusted according to specific requirements.

# %%
RESAMPLE_FREQ = 1

class Vgg19_Extractor(nn.Module):
    def __init__(self, space):
        super().__init__()
        self.vgg_layers = models.vgg19(weights=models.VGG19_Weights.DEFAULT).features

        for param in self.parameters():
            param.requires_grad = False
        self.capture_layers = set([1, 3, 6, 8, 11, 13, 15, 17, 20, 22, 24, 26, 29, 31, 33, 35])
        self.patch_match_layer=29
        self.num_max_pool = 4
        self.space = space
        
    def patch_match_features(self, x):
        feat=None
        for i in range(len(self.vgg_layers)):
            x = self.vgg_layers[i](x)
            if i == self.patch_match_layer:
                feat = x
                return feat/torch.norm(feat)
    
    def forward_base(self, x):
        feat = [x]
        for i in range(len(self.vgg_layers)):
            x = self.vgg_layers[i](x)
            if i in self.capture_layers: feat.append(x)
        return feat

    def forward(self, x):
        if self.space != 'vgg':
            x = (x + 1.) / 2.
            x = x - (torch.Tensor([0.485, 0.456, 0.406]).to(x.device).view(1, -1, 1, 1))
            x = x / (torch.Tensor([0.229, 0.224, 0.225]).to(x.device).view(1, -1, 1, 1))
        feat = self.forward_base(x)
        return feat
    
    def forward_samples_hypercolumn(self, X, samps=100):
        feat = self.forward(X)

        xx,xy = np.meshgrid(np.arange(X.shape[2]), np.arange(X.shape[3]))
        xx = np.expand_dims(xx.flatten(),1)
        xy = np.expand_dims(xy.flatten(),1)
        xc = np.concatenate([xx,xy],1)
        
        samples = min(samps,xc.shape[0])

        np.random.shuffle(xc)
        xx = xc[:samples,0]
        yy = xc[:samples,1]

        feat_samples = []
        for i in range(len(feat)):

            layer_feat = feat[i]

            # hack to detect lower resolution
            if i>0 and feat[i].size(2) < feat[i-1].size(2):
                xx = xx/2.0
                yy = yy/2.0

            xx = np.clip(xx, 0, layer_feat.shape[2]-1).astype(np.int32)
            yy = np.clip(yy, 0, layer_feat.shape[3]-1).astype(np.int32)

            features = layer_feat[:,:, xx[range(samples)], yy[range(samples)]]
            feat_samples.append(features.clone().detach())

        feat = torch.cat(feat_samples,1)
        return feat
    
    def forward_cat(self, X, r, samps=100):
        feat = self.forward(X)

        try:
            r = r[:,:,0]
        except:
            pass

        if r.max()<0.1:
            region_mask = np.greater(r.flatten()+1.,0.5)
        else:
            region_mask = np.greater(r.flatten(),0.5)

        xx,xy = np.meshgrid(np.arange(X.shape[2]), np.arange(X.shape[3]))
        xx = np.expand_dims(xx.flatten(),1)
        xy = np.expand_dims(xy.flatten(),1)
        xc = np.concatenate([xx,xy],1)

        xc = xc[region_mask,:]

        samples = min(samps,xc.shape[0])

        np.random.shuffle(xc)
        xx = xc[:samples,0]
        yy = xc[:samples,1]

        feat_samples = []
        for i in range(len(feat)):
            layer_feat = feat[i]
            # hack to detect lower resolution
            if i>0 and feat[i].size(2) < feat[i-1].size(2):
                xx = xx/2.0
                yy = yy/2.0
            
            xx = np.clip(xx, 0, layer_feat.shape[2]-1).astype(np.int32)
            yy = np.clip(yy, 0, layer_feat.shape[3]-1).astype(np.int32)

            features = layer_feat[:,:, xx[range(samples)], yy[range(samples)]]
            feat_samples.append(features.clone().detach())

        feat = torch.cat(feat_samples,1)
        return feat

# %%
RESAMPLE_FREQ = 1

class Vgg16_Extractor(nn.Module):
    def __init__(self, space):
        super().__init__()
        self.vgg_layers = models.vgg16(weights=models.VGG16_Weights.DEFAULT).features

        for param in self.parameters():
            param.requires_grad = False
        self.capture_layers = set([1,3,6,8,11,13,15,22,29])
        self.space = space
        
    def forward_base(self, x):
        feat = [x]
        for i in range(len(self.vgg_layers)):
            x = self.vgg_layers[i](x)
            if i in self.capture_layers: feat.append(x)
        return feat

    def forward(self, x):
        if self.space != 'vgg':
            x = (x + 1.) / 2.
            x = x - (torch.Tensor([0.485, 0.456, 0.406]).to(x.device).view(1, -1, 1, 1))
            x = x / (torch.Tensor([0.229, 0.224, 0.225]).to(x.device).view(1, -1, 1, 1))
        feat = self.forward_base(x)
        return feat
    
    def forward_samples_hypercolumn(self, X, samps=100):
        feat = self.forward(X)

        xx,xy = np.meshgrid(np.arange(X.shape[2]), np.arange(X.shape[3]))
        xx = np.expand_dims(xx.flatten(),1)
        xy = np.expand_dims(xy.flatten(),1)
        xc = np.concatenate([xx,xy],1)
        
        samples = min(samps,xc.shape[0])

        np.random.shuffle(xc)
        xx = xc[:samples,0]
        yy = xc[:samples,1]

        feat_samples = []
        for i in range(len(feat)):

            layer_feat = feat[i]

            # hack to detect lower resolution
            if i>0 and feat[i].size(2) < feat[i-1].size(2):
                xx = xx/2.0
                yy = yy/2.0

            xx = np.clip(xx, 0, layer_feat.shape[2]-1).astype(np.int32)
            yy = np.clip(yy, 0, layer_feat.shape[3]-1).astype(np.int32)

            features = layer_feat[:,:, xx[range(samples)], yy[range(samples)]]
            feat_samples.append(features.clone().detach())

        feat = torch.cat(feat_samples,1)
        return feat
    
    def forward_cat(self, X, r, samps=100):
        feat = self.forward(X)

        try:
            r = r[:,:,0]
        except:
            pass

        if r.max()<0.1:
            region_mask = np.greater(r.flatten()+1.,0.5)
        else:
            region_mask = np.greater(r.flatten(),0.5)

        xx,xy = np.meshgrid(np.arange(X.shape[2]), np.arange(X.shape[3]))
        xx = np.expand_dims(xx.flatten(),1)
        xy = np.expand_dims(xy.flatten(),1)
        xc = np.concatenate([xx,xy],1)

        xc = xc[region_mask,:]

        samples = min(samps,xc.shape[0])

        np.random.shuffle(xc)
        xx = xc[:samples,0]
        yy = xc[:samples,1]

        feat_samples = []
        for i in range(len(feat)):
            layer_feat = feat[i]
            # hack to detect lower resolution
            if i>0 and feat[i].size(2) < feat[i-1].size(2):
                xx = xx/2.0
                yy = yy/2.0
            
            xx = np.clip(xx, 0, layer_feat.shape[2]-1).astype(np.int32)
            yy = np.clip(yy, 0, layer_feat.shape[3]-1).astype(np.int32)

            features = layer_feat[:,:, xx[range(samples)], yy[range(samples)]]
            feat_samples.append(features.clone().detach())

        feat = torch.cat(feat_samples,1)
        return feat

# %% [markdown]
# ### Optimize

# %% [markdown]
# #### Optimizing Computation for Loss Calculation
# 1.	Random Sampling Strategy
#   - To avoid computing distances between every pixel in the style and output images, a random sampling approach is employed:
#   - Style Image: Randomly sample 1024 points.
#   - Content Image: Use a uniform grid to sample 1024 points, adding a random  x, y  offset at each sampling step to cover a broader image area.
# 2.	Efficiency in Loss Calculation
#   - Only the feature vectors corresponding to the sampled points are used for loss calculation.
#   - Gradients (used in backpropagation) are also computed only for these sampled points, avoiding unnecessary optimization over all pixels.
# 3.	Dynamic Sampling
#   - After each optimization step (using the RMSprop algorithm), the sampling positions are refreshed.
#   - This dynamic sampling strategy helps:
#   - Avoid overfitting to specific regions of the image.
#   - Gradually cover the entire image’s feature space across multiple iterations.

# %%
def optimize(result, content, style, content_path, style_path, content_weight, lr, extractor, regions=0):
    # torch.autograd.set_detect_anomaly(True)
    result_pyramid = make_laplace_pyramid(result, 5)
    result_pyramid = [l.data.requires_grad_() for l in result_pyramid]

    opt_iter = 200

    # use rmsprop
    optimizer = optim.RMSprop(result_pyramid, lr=lr)

    # extract features for content
    feat_content = extractor(content) # 

    stylized = fold_laplace_pyramid(result_pyramid)
    
    # some inner loop that extracts samples
    feat_style_all = []
    for ri in range(len(regions[0])):
        r_temp = regions[0][ri]
        if len(r_temp.shape) > 2:
            r_temp = r_temp[:,:,0]
        
        r_temp = torch.from_numpy(r_temp).unsqueeze(0).unsqueeze(0).contiguous()
        if AUTO_MASK_PYRAMID:
            r=r_temp[0,0,:,:].numpy()
        else:
            r = tensor_resample(r_temp,[style.size(3),style.size(2)])[0,0,:,:].numpy()
        feat_style = None
        for j in range(5):
            with torch.no_grad():
                feat_e = extractor.forward_cat(style, r, samps=1000)  
                feat_style = feat_e if feat_style is None else torch.cat((feat_style, feat_e), dim=2)
        feat_style_all.append(feat_style)

    xx = {}
    xy = {}
    yx = {}
        
    for ri in range(len(regions[0])):

        try:
            temp = xx[ri]
        except:
            xx[ri] = []
            xy[ri] = []
            yx[ri] = []

        r_temp = regions[0][ri]
        r_temp = torch.from_numpy(r_temp).unsqueeze(0).unsqueeze(0).contiguous()
        if AUTO_MASK_PYRAMID:
            r=r_temp[0,0,:,:].numpy()
        else:
            r = tensor_resample(r_temp, ([stylized.size(3), stylized.size(2)]))[0,0,:,:].numpy()     

        if r.max()<0.1:
            r = np.greater(r+1.,0.5)
        else:
            r = np.greater(r,0.5)
   
        sample_indices(feat_content, feat_style_all, r, ri, xx, xy, yx) # 0 to sample over first layer extracted

    # init indices to optimize over
    for it in range(opt_iter):
        optimizer.zero_grad()
        stylized = fold_laplace_pyramid(result_pyramid)
        # original code has resample here, seems pointless with uniform shuffle
        # ...
        # also shuffle them every y iter
        if it % 1 == 0 and it != 0:
            for ri in xx.keys():
                np.random.shuffle(xx[ri][0])
                np.random.shuffle(xy[ri][0])
                np.random.shuffle(yx[ri][0])

        feat_result = extractor(stylized)

        loss = calculate_loss(feat_result, feat_content, feat_style_all, xx, xy, yx, content_weight, regions)
        
        loss.backward()
        optimizer.step()
    
    return stylized

# %% [markdown]
# ## Step 5: STROTSS process
#
# 1.	Iterative Resolution Adjustment
#     - The method iteratively increases the resolution and halves the value of  \alpha  in each step.
# 2.	Initial Resolution
#     - At the start, the longer side of both the content image and style image is scaled down to 64 pixels.
#     - The output from each scaled resolution is bilinearly upsampled to twice the resolution and used as the initialization for the next scale’s output.
# 3.	Default Settings
#     - By default, the process iterates four times.
#     - The initial value of  \alpha = 16 , ensuring that  \alpha = 1  at the final resolution.
# 4.	Initialization at the Lowest Resolution
#     - At the lowest resolution:
#     - The output is initialized as the lowest level of the Laplacian pyramid of the content image, combined with the average color of the style image.
#     - This initialized image is then decomposed into a 5-level Laplacian pyramid.
# 5.	Optimization Using RMSprop
#     - RMSprop is used to update the components of the Laplacian pyramid, minimizing the objective function.
#     - Optimizing the Laplacian pyramid instead of raw pixels significantly accelerates convergence.
# 6.	Optimization Details
#     - For each resolution:
#     - RMSprop is run for 200 updates.
#     - The learning rate is set to 0.002 for all resolutions except the last one, where it is reduced to 0.001.

# %%
def strotss(content_pil, style_pil, content_path, style_path, regions, content_weight=1.0*16.0, device='cuda:0', space='uniform', content_mask=None, style_mask=None):
    content_np = pil_to_np(content_pil)
    style_np = pil_to_np(style_pil)
    content_full = np_to_tensor(content_np, space).to(device)
    style_full = np_to_tensor(style_np, space).to(device)

    if content_mask is not None and style_mask is not None:
        content_mask = content_mask.to(device)
        style_mask = style_mask.to(device)

    lr = 2e-3
    extractor = Vgg19_Extractor(space=space).to(device)

    scale_last = max(content_full.shape[2], content_full.shape[3])
    scales = []
    for scale in range(10):
        divisor = 2**scale
        if min(content_pil.width, content_pil.height) // divisor >= 33:
            scales.insert(0, divisor)
    
    for scale in scales:
        # rescale content to current scale
        content = tensor_resample(content_full, [ content_full.shape[2] // scale, content_full.shape[3] // scale ])
        style = tensor_resample(style_full, [ style_full.shape[2] // scale, style_full.shape[3] // scale ])
        if AUTO_MASK_PYRAMID:
            # using patch_match to get regions' correspondence
            # Prom1: resample——因为原本的版本中，regions就只提供一次，大小和原图一样，但是现在我们是对每一个分辨率都得到一个新的regions
            # Prom2: 我们需要将patch_match融入到我们代码当中——要研究对应的接口，希望最后能够得到两张图片正方形区域用颜色对应起来
            feat1=extractor.patch_match_features(content)
            feat2=extractor.patch_match_features(style)
            pm=PatchMatch(feat1,feat2,3)
            pm.propagate(iters=5)
            matches=pm.nnf
            im1=np_to_pil(tensor_to_np(content))
            im2=np_to_pil(tensor_to_np(style))
            regions=build_from_matches(matches,extractor.num_max_pool,im1,im2)
            
        print(f'Optimizing at resoluton [{content.shape[2]}, {content.shape[3]}]')
        # upsample or initialize the result
        if scale == scales[0]:
            # first
            result = laplacian(content) + style.mean(2,keepdim=True).mean(3,keepdim=True)
        elif scale == scales[-1]:
            # last 
            result = tensor_resample(result, [content.shape[2], content.shape[3]])
            lr = 1e-3
        else:
            result = tensor_resample(result, [content.shape[2], content.shape[3]]) + laplacian(content)

        # # do the optimization on this scale
        result = optimize(result, content, style, content_path, style_path, content_weight=content_weight, lr=lr, extractor=extractor, regions=regions)

        # next scale lower weight
        content_weight /= 2.0

    clow = -1.0 if space == 'uniform' else -1.7
    chigh = 1.0 if space == 'uniform' else 1.7
    result_image = tensor_to_np(tensor_resample(torch.clamp(result, clow, chigh), [content_full.shape[2], content_full.shape[3]])) # 
    # renormalize image
    result_image -= result_image.min()
    result_image /= result_image.max()
    return np_to_pil(result_image * 255.)

# %%
args={"content": "content.jpg", "style": "style.jpg", "content_mask": None, "style_mask": None, "weight": 1.0, "output": "strotss.png", "device": "cuda:0", "ospace": "uniform", "resize_to": 512,"AUTO_MASK_PYRAMID":False}
args["content"] ="./test_content/city.jpg"
args["style"] = "./test_style/sketch.jpg"
args["output"]=args["content"].split('/')[-1].split('.')[0]+"_"+args["style"].split('/')[-1].split('.')[0]+"_masked.png"
AUTO_MASK_PYRAMID=args["AUTO_MASK_PYRAMID"]=True
# args["content_mask"] ="/Users/xiongjiangkai/Downloads/cv_heol/test_content/content_palace_single1.jpg"
# args["style_mask"] = "/Users/xiongjiangkai/Downloads/cv_heol/test_style/vangogh_starry_night_single1.jpg"

# make 256 the smallest possible long side, will still fail if short side is <
if args["resize_to"] < 2**8:
    print("Resulution too low.")
    exit(1)

content_pil, style_pil = pil_loader(args["content"]), pil_loader(args["style"])
if AUTO_MASK_PYRAMID:
    # resize style_pil to content_pil
    style_pil = style_pil.resize(content_pil.size)
content_mask, style_mask = None, None

if args["content_mask"] and args["style_mask"] is not None:
    regions = extract_color_regions(args["content_mask"], args["style_mask"])

    pil_content_mask = pil_loader(args["content_mask"])
    pil_style_mask = pil_loader(args["style_mask"])
    
    pil_content_mask = pil_resize_long_edge_to(pil_content_mask, args["resize_to"])
    pil_style_mask = pil_resize_long_edge_to(pil_style_mask, args["resize_to"])
    
    content_mask = pil_to_np(pil_content_mask)
    style_mask = pil_to_np(pil_style_mask)

    content_mask = create_mask_from_image(content_mask)
    style_mask = create_mask_from_image(style_mask)
else:
    try:
        regions = [[pil_to_np(pil_resize_long_edge_to(content_pil, args["resize_to"]))[:,:,0]*0.+1.], [pil_to_np(pil_resize_long_edge_to(style_pil, args["resize_to"]))[:,:,0]*0.+1.]]
    except:
        regions = [[pil_to_np(pil_resize_long_edge_to(content_pil, args["resize_to"]))[:,:]*0.+1.], [pil_to_np(pil_resize_long_edge_to(style_pil, args["resize_to"]))[:,:]*0.+1.]]

content_weight = args["weight"] * 16.0

start = time()

result = strotss(pil_resize_long_edge_to(content_pil, args["resize_to"]), 
                    pil_resize_long_edge_to(style_pil, args["resize_to"]), args["content"], args["style"], regions, content_weight, device, args["ospace"], content_mask=content_mask, style_mask=style_mask)
result.save(args["output"])
print(f'Done in {time()-start:.3f}s')
# Out:
# Propagation iteration 1 done
# Propagation iteration 2 done
# Propagation iteration 3 done
# Propagation iteration 4 done
# Propagation iteration 5 done
# 最佳类别数：3, 轮廓系数：0.2823
# Optimizing at resoluton [42, 64]
# Style: 2.780, Content: 0.027
# Style: 2.475, Content: 0.014
# Style: 3.180, Content: 0.012
# Style: 2.739, Content: 0.087
# Style: 2.151, Content: 0.009
# Style: 2.961, Content: 0.008
# Style: 2.728, Content: 0.051
# Style: 2.190, Content: 0.039
# Style: 2.952, Content: 0.042
# Style: 2.675, Content: 0.073
# Style: 2.248, Content: 0.067
# Style: 2.921, Content: 0.035
# Style: 2.681, Content: 0.027
# Style: 2.013, Content: 0.007
# Style: 2.911, Content: 0.025
# Style: 2.552, Content: 0.036
# Style: 1.900, Content: 0.053
# Style: 2.834, Content: 0.028
# Style: 2.557, Content: 0.027
# Style: 1.804, Content: 0.019
# Style: 2.725, Content: 0.015
# Style: 2.476, Content: 0.035
# Style: 1.758, Content: 0.027
# Style: 2.665, Content: 0.024
# Style: 2.484, Content: 0.023
# Style: 1.750, Content: 0.011
# Style: 2.669, Content: 0.019
# Style: 2.440, Content: 0.027
# Style: 1.717, Content: 0.022
# Style: 2.633, Content: 0.013
# Style: 2.408, Content: 0.023
# Style: 1.634, Content: 0.016
# Style: 2.566, Content: 0.015
# Style: 2.374, Content: 0.025
# Style: 1.590, Content: 0.010
# Style: 2.531, Content: 0.010
# Style: 2.369, Content: 0.023
# Style: 1.560, Content: 0.010
# Style: 2.506, Content: 0.012
# Style: 2.343, Content: 0.024
# Style: 1.527, Content: 0.011
# Style: 2.481, Content: 0.012
# Style: 2.330, Content: 0.023
# Style: 1.509, Content: 0.009
# Style: 2.458, Content: 0.011
# Style: 2.291, Content: 0.025
# Style: 1.493, Content: 0.013
# Style: 2.439, Content: 0.012
# Style: 2.298, Content: 0.023
# Style: 1.478, Content: 0.011
# Style: 2.425, Content: 0.010
# Style: 2.274, Content: 0.028
# Style: 1.454, Content: 0.011
# Style: 2.398, Content: 0.013
# Style: 2.269, Content: 0.023
# Style: 1.441, Content: 0.008
# Style: 2.402, Content: 0.009
# Style: 2.233, Content: 0.025
# Style: 1.431, Content: 0.011
# Style: 2.371, Content: 0.009
# Style: 2.239, Content: 0.024
# Style: 1.400, Content: 0.011
# Style: 2.368, Content: 0.008
# Style: 2.210, Content: 0.025
# Style: 1.397, Content: 0.011
# Style: 2.359, Content: 0.008
# Style: 2.213, Content: 0.023
# Style: 1.384, Content: 0.010
# Style: 2.336, Content: 0.009
# Style: 2.192, Content: 0.025
# Style: 1.369, Content: 0.011
# Style: 2.325, Content: 0.014
# Style: 2.186, Content: 0.023
# Style: 1.356, Content: 0.010
# Style: 2.309, Content: 0.013
# Style: 2.161, Content: 0.024
# Style: 1.347, Content: 0.010
# Style: 2.290, Content: 0.011
# Style: 2.159, Content: 0.023
# Style: 1.334, Content: 0.010
# Style: 2.284, Content: 0.009
# Style: 2.135, Content: 0.023
# Style: 1.334, Content: 0.010
# Style: 2.275, Content: 0.008
# Style: 2.129, Content: 0.023
# Style: 1.313, Content: 0.011
# Style: 2.258, Content: 0.008
# Style: 2.114, Content: 0.023
# Style: 1.312, Content: 0.008
# Style: 2.256, Content: 0.008
# Style: 2.127, Content: 0.023
# Style: 1.313, Content: 0.008
# Style: 2.240, Content: 0.009
# Style: 2.110, Content: 0.028
# Style: 1.316, Content: 0.009
# Style: 2.239, Content: 0.012
# Style: 2.125, Content: 0.025
# Style: 1.303, Content: 0.009
# Style: 2.224, Content: 0.013
# Style: 2.097, Content: 0.025
# Style: 1.291, Content: 0.008
# Style: 2.205, Content: 0.012
# Style: 2.102, Content: 0.024
# Style: 1.278, Content: 0.009
# Style: 2.201, Content: 0.010
# Style: 2.085, Content: 0.024
# Style: 1.286, Content: 0.008
# Style: 2.187, Content: 0.009
# Style: 2.092, Content: 0.022
# Style: 1.277, Content: 0.010
# Style: 2.186, Content: 0.009
# Style: 2.058, Content: 0.023
# Style: 1.269, Content: 0.008
# Style: 2.170, Content: 0.008
# Style: 2.060, Content: 0.022
# Style: 1.253, Content: 0.008
# Style: 2.159, Content: 0.009
# Style: 2.045, Content: 0.024
# Style: 1.257, Content: 0.009
# Style: 2.163, Content: 0.010
# Style: 2.053, Content: 0.022
# Style: 1.255, Content: 0.009
# Style: 2.145, Content: 0.011
# Style: 2.046, Content: 0.024
# Style: 1.251, Content: 0.008
# Style: 2.136, Content: 0.014
# Style: 2.039, Content: 0.022
# Style: 1.231, Content: 0.008
# Style: 2.128, Content: 0.011
# Style: 2.029, Content: 0.023
# Style: 1.240, Content: 0.008
# Style: 2.117, Content: 0.010
# Style: 2.036, Content: 0.022
# Style: 1.223, Content: 0.008
# Style: 2.109, Content: 0.009
# Style: 2.016, Content: 0.023
# Style: 1.236, Content: 0.008
# Style: 2.100, Content: 0.009
# Style: 2.038, Content: 0.022
# Style: 1.217, Content: 0.009
# Style: 2.081, Content: 0.010
# Style: 2.005, Content: 0.022
# Style: 1.226, Content: 0.007
# Style: 2.108, Content: 0.009
# Style: 2.001, Content: 0.026
# Style: 1.209, Content: 0.009
# Style: 2.079, Content: 0.009
# Style: 2.029, Content: 0.028
# Style: 1.232, Content: 0.007
# Style: 2.110, Content: 0.008
# Style: 2.012, Content: 0.024
# Style: 1.204, Content: 0.008
# Style: 2.076, Content: 0.009
# Style: 2.001, Content: 0.022
# Style: 1.223, Content: 0.006
# Style: 2.060, Content: 0.008
# Style: 1.989, Content: 0.023
# Style: 1.201, Content: 0.009
# Style: 2.054, Content: 0.009
# Style: 2.005, Content: 0.023
# Style: 1.204, Content: 0.007
# Style: 2.060, Content: 0.008
# Style: 1.991, Content: 0.022
# Style: 1.191, Content: 0.009
# Style: 2.034, Content: 0.011
# Style: 1.976, Content: 0.027
# Style: 1.211, Content: 0.007
# Style: 2.033, Content: 0.015
# Style: 1.997, Content: 0.024
# Style: 1.195, Content: 0.009
# Style: 2.047, Content: 0.014
# Style: 1.976, Content: 0.026
# Style: 1.196, Content: 0.007
# Style: 2.033, Content: 0.013
# Style: 1.977, Content: 0.023
# Style: 1.177, Content: 0.009
# Style: 2.020, Content: 0.010
# Style: 1.964, Content: 0.023
# Style: 1.189, Content: 0.005
# Style: 1.995, Content: 0.009
# Style: 1.968, Content: 0.022
# Style: 1.167, Content: 0.008
# Style: 1.990, Content: 0.009
# Style: 1.953, Content: 0.023
# Style: 1.180, Content: 0.007
# Style: 1.985, Content: 0.009
# Style: 1.957, Content: 0.023
# Style: 1.161, Content: 0.010
# Style: 1.974, Content: 0.009
# Style: 1.948, Content: 0.023
# Style: 1.177, Content: 0.006
# Style: 1.982, Content: 0.009
# Style: 1.948, Content: 0.023
# Style: 1.156, Content: 0.009
# Style: 1.964, Content: 0.010
# Style: 1.948, Content: 0.024
# Style: 1.171, Content: 0.007
# Style: 1.976, Content: 0.010
# Style: 1.949, Content: 0.024
# Style: 1.153, Content: 0.010
# Style: 1.973, Content: 0.010
# Style: 1.949, Content: 0.024
# Style: 1.176, Content: 0.006
# Style: 1.982, Content: 0.010
# Style: 1.942, Content: 0.024
# Style: 1.150, Content: 0.008
# Style: 1.952, Content: 0.009
# Style: 1.939, Content: 0.023
# Style: 1.167, Content: 0.006
# Style: 1.961, Content: 0.008
# Style: 1.929, Content: 0.023
# Style: 1.152, Content: 0.008
# Style: 1.952, Content: 0.009
# Style: 1.931, Content: 0.023
# Style: 1.158, Content: 0.005
# Style: 1.966, Content: 0.008
# Style: 1.927, Content: 0.022
# Style: 1.139, Content: 0.008
# Style: 1.951, Content: 0.009
# Style: 1.921, Content: 0.023
# Style: 1.148, Content: 0.007
# Style: 1.937, Content: 0.009
# Style: 1.952, Content: 0.023
# Style: 1.136, Content: 0.011
# Style: 1.957, Content: 0.011
# Style: 1.926, Content: 0.027
# Style: 1.150, Content: 0.005
# Style: 1.954, Content: 0.014
# Style: 1.923, Content: 0.024
# Style: 1.136, Content: 0.008
# Style: 1.929, Content: 0.010
# Style: 1.914, Content: 0.025
# Style: 1.144, Content: 0.007
# Style: 1.934, Content: 0.010
# Style: 1.916, Content: 0.023
# Style: 1.125, Content: 0.011
# Style: 1.945, Content: 0.009
# Style: 1.901, Content: 0.024
# Style: 1.132, Content: 0.005
# Style: 1.911, Content: 0.009
# Style: 1.906, Content: 0.022
# Style: 1.118, Content: 0.009
# Style: 1.896, Content: 0.009
# Style: 1.897, Content: 0.023
# Style: 1.134, Content: 0.006
# Style: 1.913, Content: 0.009
# Style: 1.900, Content: 0.023
# Style: 1.111, Content: 0.010
# Style: 1.906, Content: 0.009
# Style: 1.903, Content: 0.023
# Style: 1.134, Content: 0.005
# Style: 1.905, Content: 0.008
# Style: 1.907, Content: 0.023
# Style: 1.109, Content: 0.008
# Style: 1.893, Content: 0.009
# Style: 1.899, Content: 0.024
# Style: 1.130, Content: 0.006
# Style: 1.890, Content: 0.009
# Style: 1.895, Content: 0.024
# Style: 1.102, Content: 0.009
# Style: 1.863, Content: 0.009
# Style: 1.885, Content: 0.023
# Style: 1.117, Content: 0.005
# Style: 1.908, Content: 0.009
# Style: 1.884, Content: 0.023
# Style: 1.095, Content: 0.008
# Style: 1.873, Content: 0.009
# Style: 1.877, Content: 0.023
# Style: 1.111, Content: 0.006
# Style: 1.872, Content: 0.009
# Style: 1.887, Content: 0.023
# Style: 1.091, Content: 0.010
# Style: 1.855, Content: 0.010
# Style: 1.871, Content: 0.026
# Style: 1.104, Content: 0.005
# Style: 1.848, Content: 0.011
# Style: 1.883, Content: 0.023
# Style: 1.094, Content: 0.007
# Style: 1.865, Content: 0.011
# Style: 1.891, Content: 0.026
# Style: 1.122, Content: 0.005
# Style: 1.847, Content: 0.012
# Style: 1.877, Content: 0.023
# Style: 1.084, Content: 0.009
# Style: 1.832, Content: 0.010
# Style: 1.861, Content: 0.024
# Style: 1.093, Content: 0.005
# Style: 1.827, Content: 0.010
# Style: 1.868, Content: 0.023
# Style: 1.077, Content: 0.009
# Style: 1.824, Content: 0.010
# Style: 1.873, Content: 0.023
# Style: 1.104, Content: 0.006
# Style: 1.828, Content: 0.009
# Style: 1.871, Content: 0.023
# Style: 1.072, Content: 0.011
# Style: 1.833, Content: 0.009
# Style: 1.867, Content: 0.024
# Style: 1.097, Content: 0.004
# Style: 1.828, Content: 0.008
# Style: 1.873, Content: 0.024
# Style: 1.069, Content: 0.008
# Style: 1.806, Content: 0.009
# Style: 1.866, Content: 0.024
# Style: 1.086, Content: 0.005
# Style: 1.819, Content: 0.008
# Style: 1.858, Content: 0.023
# Style: 1.062, Content: 0.009
# Style: 1.805, Content: 0.009
# Style: 1.851, Content: 0.023
# Style: 1.082, Content: 0.005
# Style: 1.809, Content: 0.008
# Style: 1.851, Content: 0.023
# Style: 1.058, Content: 0.009
# Style: 1.792, Content: 0.009
# Style: 1.844, Content: 0.024
# Style: 1.075, Content: 0.004
# Style: 1.795, Content: 0.009
# Style: 1.849, Content: 0.023
# Style: 1.060, Content: 0.009
# Style: 1.792, Content: 0.010
# Style: 1.842, Content: 0.025
# Style: 1.068, Content: 0.004
# Style: 1.788, Content: 0.011
# Style: 1.851, Content: 0.024
# Style: 1.060, Content: 0.008
# Style: 1.788, Content: 0.010
# Style: 1.845, Content: 0.026
# Style: 1.077, Content: 0.005
# Style: 1.782, Content: 0.011
# Style: 1.834, Content: 0.023
# Style: 1.053, Content: 0.009
# Style: 1.789, Content: 0.009
# Style: 1.844, Content: 0.025
# Style: 1.070, Content: 0.005
# Style: 1.767, Content: 0.009
# Style: 1.825, Content: 0.023
# Style: 1.043, Content: 0.009
# Style: 1.781, Content: 0.009
# Style: 1.832, Content: 0.023
# Style: 1.060, Content: 0.005
# Style: 1.766, Content: 0.009
# Style: 1.825, Content: 0.024
# Style: 1.040, Content: 0.009
# Style: 1.756, Content: 0.009
# Style: 1.833, Content: 0.024
# Style: 1.060, Content: 0.004
# Style: 1.770, Content: 0.009
# Style: 1.832, Content: 0.024
# Style: 1.044, Content: 0.008
# Style: 1.755, Content: 0.010
# Style: 1.843, Content: 0.024
# Style: 1.083, Content: 0.005
# Style: 1.770, Content: 0.009
# Style: 1.821, Content: 0.024
# Style: 1.044, Content: 0.008
# Style: 1.745, Content: 0.009
# Style: 1.825, Content: 0.024
# Style: 1.053, Content: 0.005
# Style: 1.756, Content: 0.008
# Style: 1.814, Content: 0.023
# Style: 1.031, Content: 0.008
# Style: 1.755, Content: 0.009
# Style: 1.812, Content: 0.024
# Style: 1.046, Content: 0.004
# Style: 1.756, Content: 0.009
# Style: 1.812, Content: 0.023
# Style: 1.050, Content: 0.009
# Style: 1.734, Content: 0.009
# Style: 1.811, Content: 0.025
# Style: 1.042, Content: 0.004
# Style: 1.733, Content: 0.009
# Style: 1.818, Content: 0.024
# Style: 1.029, Content: 0.009
# Style: 1.758, Content: 0.010
# Style: 1.808, Content: 0.027
# Style: 1.037, Content: 0.004
# Style: 1.742, Content: 0.011
# Style: 1.825, Content: 0.024
# Style: 1.026, Content: 0.008
# Style: 1.736, Content: 0.011
# Style: 1.810, Content: 0.025
# Style: 1.034, Content: 0.004
# Style: 1.731, Content: 0.012
# Style: 1.804, Content: 0.023
# Style: 1.020, Content: 0.008
# Style: 1.741, Content: 0.009
# Style: 1.795, Content: 0.024
# Style: 1.026, Content: 0.004
# Style: 1.717, Content: 0.009
# Style: 1.797, Content: 0.023
# Style: 1.034, Content: 0.009
# Style: 1.710, Content: 0.010
# Style: 1.800, Content: 0.024
# Style: 1.027, Content: 0.004
# Style: 1.713, Content: 0.009
# Style: 1.797, Content: 0.023
# Style: 1.010, Content: 0.009
# Style: 1.702, Content: 0.009
# Style: 1.783, Content: 0.024
# Style: 1.023, Content: 0.004
# Style: 1.710, Content: 0.009
# Style: 1.788, Content: 0.024
# Style: 1.007, Content: 0.008
# Style: 1.691, Content: 0.010
# Style: 1.795, Content: 0.024
# Style: 1.027, Content: 0.005
# Style: 1.714, Content: 0.008
# Style: 1.788, Content: 0.025
# Style: 1.002, Content: 0.009
# Style: 1.691, Content: 0.009
# Style: 1.796, Content: 0.024
# Style: 1.017, Content: 0.003
# Style: 1.727, Content: 0.008
# Style: 1.777, Content: 0.025
# Style: 1.006, Content: 0.004
# Style: 1.684, Content: 0.009
# Style: 1.780, Content: 0.024
# Style: 1.019, Content: 0.005
# Style: 1.718, Content: 0.008
# Style: 1.779, Content: 0.023
# Style: 0.996, Content: 0.010
# Style: 1.684, Content: 0.009
# Style: 1.772, Content: 0.024
# Style: 1.006, Content: 0.003
# Style: 1.689, Content: 0.008
# Style: 1.772, Content: 0.024
# Style: 0.993, Content: 0.006
# Style: 1.676, Content: 0.010
# Style: 1.766, Content: 0.025
# Style: 1.008, Content: 0.005
# Style: 1.708, Content: 0.010
# Style: 1.780, Content: 0.024
# Style: 0.989, Content: 0.010
# Style: 1.678, Content: 0.012
# Style: 1.771, Content: 0.026
# Style: 0.997, Content: 0.003
# Style: 1.687, Content: 0.012
# Style: 1.777, Content: 0.024
# Style: 0.991, Content: 0.007
# Style: 1.673, Content: 0.011
# Style: 1.772, Content: 0.026
# Style: 1.001, Content: 0.004
# Style: 1.675, Content: 0.010
# Style: 1.773, Content: 0.024
# Style: 0.983, Content: 0.009
# Style: 1.693, Content: 0.010
# Style: 1.765, Content: 0.025
# Style: 0.992, Content: 0.004
# Style: 1.682, Content: 0.009
# Style: 1.768, Content: 0.024
# Style: 0.988, Content: 0.006
# Style: 1.675, Content: 0.009
# Style: 1.755, Content: 0.024
# Style: 0.991, Content: 0.005
# Style: 1.663, Content: 0.008
# Style: 1.760, Content: 0.023
# Style: 0.975, Content: 0.009
# Style: 1.656, Content: 0.009
# Style: 1.759, Content: 0.024
# Style: 0.992, Content: 0.004
# Style: 1.672, Content: 0.009
# Style: 1.762, Content: 0.024
# Style: 1.001, Content: 0.007
# Style: 1.662, Content: 0.009
# Style: 1.761, Content: 0.024
# Style: 0.995, Content: 0.005
# Style: 1.670, Content: 0.008
# Style: 1.755, Content: 0.025
# Style: 0.975, Content: 0.009
# Style: 1.663, Content: 0.009
# Style: 1.757, Content: 0.025
# Style: 0.989, Content: 0.003
# Style: 1.659, Content: 0.008
# Style: 1.754, Content: 0.024
# Style: 0.975, Content: 0.004
# Style: 1.641, Content: 0.009
# Style: 1.753, Content: 0.024
# Style: 0.990, Content: 0.005
# Style: 1.654, Content: 0.008
# Style: 1.745, Content: 0.023
# Style: 0.964, Content: 0.009
# Style: 1.643, Content: 0.009
# Style: 1.741, Content: 0.024
# Style: 0.980, Content: 0.004
# Style: 1.643, Content: 0.009
# Style: 1.741, Content: 0.024
# Style: 0.978, Content: 0.007
# Style: 1.633, Content: 0.010
# Style: 1.734, Content: 0.025
# Style: 0.973, Content: 0.004
# Style: 1.640, Content: 0.010
# Style: 1.755, Content: 0.024
# Style: 0.970, Content: 0.009
# Style: 1.650, Content: 0.011
# Style: 1.736, Content: 0.026
# Style: 0.972, Content: 0.003
# Style: 1.634, Content: 0.011
# Style: 1.750, Content: 0.023
# Style: 0.976, Content: 0.005
# Style: 1.629, Content: 0.010
# Style: 1.736, Content: 0.026
# Style: 0.979, Content: 0.004
# Style: 1.633, Content: 0.010
# Style: 1.736, Content: 0.024
# Style: 0.962, Content: 0.009
# Style: 1.627, Content: 0.009
# Style: 1.730, Content: 0.024
# Style: 0.963, Content: 0.003
# Style: 1.633, Content: 0.009
# Style: 1.729, Content: 0.024
# Style: 0.962, Content: 0.004
# Style: 1.630, Content: 0.009
# Style: 1.724, Content: 0.025
# Style: 0.969, Content: 0.005
# Style: 1.635, Content: 0.009
# Style: 1.727, Content: 0.024
# Style: 0.948, Content: 0.010
# Style: 1.621, Content: 0.009
# Style: 1.728, Content: 0.023
# Style: 0.969, Content: 0.004
# Style: 1.623, Content: 0.009
# Style: 1.730, Content: 0.025
# Style: 0.970, Content: 0.006
# Style: 1.608, Content: 0.009
# Style: 1.734, Content: 0.025
# Style: 0.981, Content: 0.005
# Style: 1.627, Content: 0.008
# Style: 1.724, Content: 0.025
# Style: 0.953, Content: 0.009
# Style: 1.602, Content: 0.009
# Style: 1.729, Content: 0.024
# Style: 0.984, Content: 0.003
# Style: 1.629, Content: 0.008
# Style: 1.718, Content: 0.025
# Style: 0.964, Content: 0.004
# Style: 1.598, Content: 0.009
# Style: 1.721, Content: 0.024
# Style: 0.962, Content: 0.005
# Style: 1.600, Content: 0.008
# Style: 1.706, Content: 0.024
# Style: 0.940, Content: 0.009
# Style: 1.596, Content: 0.009
# Style: 1.710, Content: 0.025
# Style: 0.972, Content: 0.003
# Style: 1.592, Content: 0.008
# Style: 1.704, Content: 0.024
# Style: 0.948, Content: 0.005
# Style: 1.602, Content: 0.009
# Style: 1.706, Content: 0.025
# Style: 0.955, Content: 0.005
# Style: 1.589, Content: 0.009
# Style: 1.708, Content: 0.024
# Style: 0.943, Content: 0.009
# Style: 1.601, Content: 0.010
# Style: 1.706, Content: 0.026
# Style: 0.959, Content: 0.004
# Style: 1.588, Content: 0.010
# Style: 1.716, Content: 0.024
# Style: 0.939, Content: 0.007
# Style: 1.586, Content: 0.012
# Style: 1.701, Content: 0.026
# Style: 0.945, Content: 0.004
# Style: 1.584, Content: 0.011
# Style: 1.713, Content: 0.024
# Style: 0.936, Content: 0.008
# Style: 1.581, Content: 0.010
# Style: 1.689, Content: 0.026
# Style: 0.949, Content: 0.004
# Style: 1.574, Content: 0.010
# Style: 1.704, Content: 0.025
# Style: 0.939, Content: 0.006
# Style: 1.575, Content: 0.009
# Style: 1.694, Content: 0.026
# Style: 0.947, Content: 0.004
# Style: 1.576, Content: 0.009
# Style: 1.693, Content: 0.024
# Style: 0.932, Content: 0.008
# Style: 1.591, Content: 0.009
# Style: 1.691, Content: 0.025
# Style: 0.939, Content: 0.004
# Style: 1.572, Content: 0.009
# Style: 1.692, Content: 0.024
# Style: 0.936, Content: 0.006
# Style: 1.566, Content: 0.009
# Style: 1.684, Content: 0.025
# Style: 0.942, Content: 0.004
# Style: 1.559, Content: 0.009
# Style: 1.699, Content: 0.024
# Style: 0.927, Content: 0.008
# Style: 1.566, Content: 0.009
# Style: 1.685, Content: 0.025
# Style: 0.936, Content: 0.004
# Style: 1.561, Content: 0.008
# Style: 1.685, Content: 0.025
# Style: 0.950, Content: 0.007
# Style: 1.561, Content: 0.009
# Style: 1.710, Content: 0.026
# Style: 0.962, Content: 0.005
# Style: 1.600, Content: 0.008
# Propagation iteration 1 done
# Propagation iteration 2 done
# Propagation iteration 3 done
# Propagation iteration 4 done
# Propagation iteration 5 done
# 最佳类别数：5, 轮廓系数：0.3128
# Optimizing at resoluton [84, 128]
# Style: 2.060, Content: 0.050
# Style: 2.256, Content: 0.037
# Style: 2.211, Content: 0.051
# Style: 2.544, Content: 0.062
# Style: 2.354, Content: 0.039
# Style: 2.021, Content: 0.046
# Style: 2.230, Content: 0.050
# Style: 2.104, Content: 0.053
# Style: 2.552, Content: 0.039
# Style: 2.310, Content: 0.113
# Style: 1.885, Content: 0.075
# Style: 1.979, Content: 0.060
# Style: 1.882, Content: 0.062
# Style: 2.386, Content: 0.041
# Style: 2.164, Content: 0.076
# Style: 1.750, Content: 0.048
# Style: 1.940, Content: 0.044
# Style: 1.815, Content: 0.049
# Style: 2.302, Content: 0.046
# Style: 2.123, Content: 0.041
# Style: 1.700, Content: 0.047
# Style: 1.884, Content: 0.042
# Style: 1.784, Content: 0.052
# Style: 2.221, Content: 0.040
# Style: 2.069, Content: 0.040
# Style: 1.632, Content: 0.052
# Style: 1.811, Content: 0.048
# Style: 1.706, Content: 0.050
# Style: 2.195, Content: 0.035
# Style: 1.971, Content: 0.049
# Style: 1.656, Content: 0.041
# Style: 1.851, Content: 0.043
# Style: 1.707, Content: 0.048
# Style: 2.146, Content: 0.030
# Style: 2.062, Content: 0.034
# Style: 1.582, Content: 0.045
# Style: 1.798, Content: 0.037
# Style: 1.657, Content: 0.041
# Style: 2.115, Content: 0.027
# Style: 1.943, Content: 0.036
# Style: 1.576, Content: 0.039
# Style: 1.773, Content: 0.034
# Style: 1.649, Content: 0.038
# Style: 2.094, Content: 0.024
# Style: 1.943, Content: 0.030
# Style: 1.559, Content: 0.039
# Style: 1.770, Content: 0.032
# Style: 1.624, Content: 0.037
# Style: 2.071, Content: 0.026
# Style: 1.909, Content: 0.036
# Style: 1.544, Content: 0.040
# Style: 1.745, Content: 0.035
# Style: 1.611, Content: 0.036
# Style: 2.047, Content: 0.030
# Style: 1.913, Content: 0.030
# Style: 1.517, Content: 0.040
# Style: 1.743, Content: 0.032
# Style: 1.595, Content: 0.036
# Style: 2.022, Content: 0.026
# Style: 1.871, Content: 0.032
# Style: 1.522, Content: 0.039
# Style: 1.721, Content: 0.032
# Style: 1.589, Content: 0.035
# Style: 2.023, Content: 0.027
# Style: 1.871, Content: 0.024
# Style: 1.518, Content: 0.049
# Style: 1.705, Content: 0.031
# Style: 1.574, Content: 0.037
# Style: 1.984, Content: 0.028
# Style: 1.834, Content: 0.028
# Style: 1.520, Content: 0.044
# Style: 1.710, Content: 0.031
# Style: 1.586, Content: 0.034
# Style: 1.996, Content: 0.031
# Style: 1.849, Content: 0.022
# Style: 1.498, Content: 0.041
# Style: 1.692, Content: 0.029
# Style: 1.562, Content: 0.036
# Style: 1.966, Content: 0.024
# Style: 1.813, Content: 0.024
# Style: 1.479, Content: 0.039
# Style: 1.680, Content: 0.032
# Style: 1.545, Content: 0.037
# Style: 1.971, Content: 0.022
# Style: 1.803, Content: 0.023
# Style: 1.486, Content: 0.037
# Style: 1.696, Content: 0.031
# Style: 1.558, Content: 0.038
# Style: 1.950, Content: 0.022
# Style: 1.814, Content: 0.026
# Style: 1.474, Content: 0.040
# Style: 1.665, Content: 0.036
# Style: 1.537, Content: 0.039
# Style: 1.956, Content: 0.023
# Style: 1.776, Content: 0.021
# Style: 1.476, Content: 0.036
# Style: 1.674, Content: 0.033
# Style: 1.535, Content: 0.036
# Style: 1.932, Content: 0.021
# Style: 1.776, Content: 0.017
# Style: 1.465, Content: 0.037
# Style: 1.657, Content: 0.030
# Style: 1.517, Content: 0.035
# Style: 1.934, Content: 0.022
# Style: 1.745, Content: 0.018
# Style: 1.468, Content: 0.035
# Style: 1.656, Content: 0.029
# Style: 1.516, Content: 0.034
# Style: 1.919, Content: 0.021
# Style: 1.756, Content: 0.017
# Style: 1.447, Content: 0.036
# Style: 1.644, Content: 0.030
# Style: 1.500, Content: 0.034
# Style: 1.914, Content: 0.024
# Style: 1.735, Content: 0.019
# Style: 1.452, Content: 0.034
# Style: 1.647, Content: 0.029
# Style: 1.501, Content: 0.034
# Style: 1.912, Content: 0.022
# Style: 1.800, Content: 0.018
# Style: 1.450, Content: 0.035
# Style: 1.632, Content: 0.031
# Style: 1.497, Content: 0.035
# Style: 1.918, Content: 0.026
# Style: 1.758, Content: 0.019
# Style: 1.445, Content: 0.039
# Style: 1.629, Content: 0.030
# Style: 1.505, Content: 0.034
# Style: 1.893, Content: 0.022
# Style: 1.729, Content: 0.020
# Style: 1.453, Content: 0.040
# Style: 1.640, Content: 0.030
# Style: 1.496, Content: 0.034
# Style: 1.902, Content: 0.023
# Style: 1.739, Content: 0.022
# Style: 1.443, Content: 0.037
# Style: 1.630, Content: 0.031
# Style: 1.496, Content: 0.035
# Style: 1.889, Content: 0.021
# Style: 1.729, Content: 0.027
# Style: 1.431, Content: 0.034
# Style: 1.630, Content: 0.029
# Style: 1.491, Content: 0.034
# Style: 1.884, Content: 0.024
# Style: 1.736, Content: 0.019
# Style: 1.429, Content: 0.035
# Style: 1.624, Content: 0.030
# Style: 1.476, Content: 0.034
# Style: 1.886, Content: 0.021
# Style: 1.701, Content: 0.021
# Style: 1.432, Content: 0.033
# Style: 1.624, Content: 0.030
# Style: 1.480, Content: 0.035
# Style: 1.873, Content: 0.022
# Style: 1.720, Content: 0.016
# Style: 1.424, Content: 0.035
# Style: 1.611, Content: 0.031
# Style: 1.474, Content: 0.034
# Style: 1.866, Content: 0.022
# Style: 1.690, Content: 0.018
# Style: 1.429, Content: 0.033
# Style: 1.605, Content: 0.031
# Style: 1.481, Content: 0.035
# Style: 1.866, Content: 0.021
# Style: 1.705, Content: 0.019
# Style: 1.426, Content: 0.032
# Style: 1.607, Content: 0.030
# Style: 1.469, Content: 0.033
# Style: 1.867, Content: 0.021
# Style: 1.693, Content: 0.021
# Style: 1.415, Content: 0.032
# Style: 1.606, Content: 0.030
# Style: 1.454, Content: 0.034
# Style: 1.857, Content: 0.020
# Style: 1.691, Content: 0.018
# Style: 1.425, Content: 0.032
# Style: 1.604, Content: 0.028
# Style: 1.459, Content: 0.032
# Style: 1.857, Content: 0.021
# Style: 1.703, Content: 0.018
# Style: 1.408, Content: 0.033
# Style: 1.596, Content: 0.028
# Style: 1.470, Content: 0.033
# Style: 1.847, Content: 0.021
# Style: 1.682, Content: 0.018
# Style: 1.414, Content: 0.032
# Style: 1.601, Content: 0.028
# Style: 1.450, Content: 0.032
# Style: 1.862, Content: 0.021
# Style: 1.701, Content: 0.019
# Style: 1.401, Content: 0.034
# Style: 1.588, Content: 0.029
# Style: 1.460, Content: 0.034
# Style: 1.844, Content: 0.023
# Style: 1.674, Content: 0.018
# Style: 1.409, Content: 0.034
# Style: 1.596, Content: 0.029
# Style: 1.443, Content: 0.032
# Style: 1.859, Content: 0.024
# Style: 1.675, Content: 0.019
# Style: 1.405, Content: 0.036
# Style: 1.577, Content: 0.029
# Style: 1.453, Content: 0.034
# Style: 1.845, Content: 0.023
# Style: 1.700, Content: 0.019
# Style: 1.398, Content: 0.035
# Style: 1.584, Content: 0.028
# Style: 1.446, Content: 0.033
# Style: 1.841, Content: 0.026
# Style: 1.673, Content: 0.016
# Style: 1.397, Content: 0.035
# Style: 1.560, Content: 0.031
# Style: 1.450, Content: 0.035
# Style: 1.829, Content: 0.022
# Style: 1.676, Content: 0.020
# Style: 1.399, Content: 0.034
# Style: 1.585, Content: 0.028
# Style: 1.428, Content: 0.033
# Style: 1.848, Content: 0.023
# Style: 1.692, Content: 0.020
# Style: 1.397, Content: 0.034
# Style: 1.581, Content: 0.028
# Style: 1.444, Content: 0.033
# Style: 1.823, Content: 0.021
# Style: 1.687, Content: 0.020
# Style: 1.399, Content: 0.033
# Style: 1.564, Content: 0.029
# Style: 1.433, Content: 0.034
# Style: 1.827, Content: 0.022
# Style: 1.677, Content: 0.024
# Style: 1.389, Content: 0.032
# Style: 1.574, Content: 0.028
# Style: 1.430, Content: 0.033
# Style: 1.821, Content: 0.021
# Style: 1.669, Content: 0.017
# Style: 1.393, Content: 0.032
# Style: 1.569, Content: 0.030
# Style: 1.418, Content: 0.034
# Style: 1.828, Content: 0.021
# Style: 1.648, Content: 0.018
# Style: 1.394, Content: 0.032
# Style: 1.569, Content: 0.028
# Style: 1.430, Content: 0.033
# Style: 1.810, Content: 0.021
# Style: 1.663, Content: 0.014
# Style: 1.385, Content: 0.033
# Style: 1.561, Content: 0.031
# Style: 1.424, Content: 0.035
# Style: 1.818, Content: 0.021
# Style: 1.634, Content: 0.017
# Style: 1.384, Content: 0.031
# Style: 1.567, Content: 0.030
# Style: 1.426, Content: 0.035
# Style: 1.807, Content: 0.021
# Style: 1.664, Content: 0.014
# Style: 1.380, Content: 0.032
# Style: 1.557, Content: 0.031
# Style: 1.423, Content: 0.033
# Style: 1.811, Content: 0.021
# Style: 1.633, Content: 0.017
# Style: 1.378, Content: 0.031
# Style: 1.568, Content: 0.028
# Style: 1.424, Content: 0.033
# Style: 1.801, Content: 0.021
# Style: 1.656, Content: 0.016
# Style: 1.378, Content: 0.032
# Style: 1.556, Content: 0.029
# Style: 1.410, Content: 0.033
# Style: 1.804, Content: 0.020
# Style: 1.639, Content: 0.018
# Style: 1.375, Content: 0.031
# Style: 1.571, Content: 0.027
# Style: 1.415, Content: 0.033
# Style: 1.799, Content: 0.021
# Style: 1.647, Content: 0.024
# Style: 1.386, Content: 0.032
# Style: 1.545, Content: 0.029
# Style: 1.419, Content: 0.033
# Style: 1.803, Content: 0.022
# Style: 1.643, Content: 0.018
# Style: 1.370, Content: 0.032
# Style: 1.552, Content: 0.028
# Style: 1.401, Content: 0.033
# Style: 1.796, Content: 0.021
# Style: 1.640, Content: 0.020
# Style: 1.371, Content: 0.033
# Style: 1.545, Content: 0.029
# Style: 1.396, Content: 0.033
# Style: 1.789, Content: 0.024
# Style: 1.634, Content: 0.018
# Style: 1.368, Content: 0.034
# Style: 1.541, Content: 0.029
# Style: 1.400, Content: 0.033
# Style: 1.796, Content: 0.021
# Style: 1.633, Content: 0.019
# Style: 1.372, Content: 0.033
# Style: 1.542, Content: 0.029
# Style: 1.396, Content: 0.034
# Style: 1.796, Content: 0.023
# Style: 1.631, Content: 0.016
# Style: 1.376, Content: 0.032
# Style: 1.546, Content: 0.029
# Style: 1.406, Content: 0.033
# Style: 1.803, Content: 0.022
# Style: 1.627, Content: 0.017
# Style: 1.357, Content: 0.031
# Style: 1.543, Content: 0.029
# Style: 1.400, Content: 0.033
# Style: 1.783, Content: 0.024
# Style: 1.624, Content: 0.015
# Style: 1.357, Content: 0.033
# Style: 1.534, Content: 0.030
# Style: 1.398, Content: 0.033
# Style: 1.791, Content: 0.021
# Style: 1.616, Content: 0.017
# Style: 1.355, Content: 0.031
# Style: 1.539, Content: 0.029
# Style: 1.402, Content: 0.033
# Style: 1.781, Content: 0.022
# Style: 1.626, Content: 0.015
# Style: 1.356, Content: 0.032
# Style: 1.528, Content: 0.030
# Style: 1.389, Content: 0.034
# Style: 1.783, Content: 0.021
# Style: 1.608, Content: 0.016
# Style: 1.349, Content: 0.032
# Style: 1.536, Content: 0.028
# Style: 1.385, Content: 0.033
# Style: 1.783, Content: 0.022
# Style: 1.620, Content: 0.015
# Style: 1.353, Content: 0.031
# Style: 1.528, Content: 0.028
# Style: 1.384, Content: 0.033
# Style: 1.797, Content: 0.020
# Style: 1.604, Content: 0.018
# Style: 1.349, Content: 0.031
# Style: 1.535, Content: 0.028
# Style: 1.389, Content: 0.033
# Style: 1.768, Content: 0.022
# Style: 1.630, Content: 0.017
# Style: 1.347, Content: 0.031
# Style: 1.526, Content: 0.028
# Style: 1.385, Content: 0.033
# Style: 1.783, Content: 0.023
# Style: 1.615, Content: 0.018
# Style: 1.346, Content: 0.031
# Style: 1.517, Content: 0.029
# Style: 1.374, Content: 0.034
# Style: 1.771, Content: 0.022
# Style: 1.612, Content: 0.016
# Style: 1.349, Content: 0.031
# Style: 1.528, Content: 0.028
# Style: 1.391, Content: 0.032
# Style: 1.773, Content: 0.021
# Style: 1.625, Content: 0.017
# Style: 1.352, Content: 0.032
# Style: 1.514, Content: 0.029
# Style: 1.370, Content: 0.034
# Style: 1.762, Content: 0.021
# Style: 1.608, Content: 0.017
# Style: 1.346, Content: 0.032
# Style: 1.517, Content: 0.029
# Style: 1.382, Content: 0.032
# Style: 1.776, Content: 0.020
# Style: 1.609, Content: 0.017
# Style: 1.340, Content: 0.032
# Style: 1.510, Content: 0.030
# Style: 1.377, Content: 0.033
# Style: 1.761, Content: 0.021
# Style: 1.620, Content: 0.016
# Style: 1.341, Content: 0.031
# Style: 1.518, Content: 0.028
# Style: 1.366, Content: 0.033
# Style: 1.773, Content: 0.021
# Style: 1.618, Content: 0.017
# Style: 1.337, Content: 0.031
# Style: 1.503, Content: 0.029
# Style: 1.374, Content: 0.034
# Style: 1.757, Content: 0.023
# Style: 1.595, Content: 0.016
# Style: 1.337, Content: 0.032
# Style: 1.514, Content: 0.029
# Style: 1.368, Content: 0.033
# Style: 1.775, Content: 0.024
# Style: 1.604, Content: 0.016
# Style: 1.330, Content: 0.032
# Style: 1.506, Content: 0.029
# Style: 1.374, Content: 0.034
# Style: 1.756, Content: 0.022
# Style: 1.594, Content: 0.016
# Style: 1.331, Content: 0.032
# Style: 1.515, Content: 0.028
# Style: 1.360, Content: 0.034
# Style: 1.762, Content: 0.022
# Style: 1.587, Content: 0.017
# Style: 1.343, Content: 0.033
# Style: 1.501, Content: 0.029
# Style: 1.364, Content: 0.034
# Style: 1.757, Content: 0.022
# Style: 1.592, Content: 0.015
# Style: 1.330, Content: 0.033
# Style: 1.506, Content: 0.029
# Style: 1.357, Content: 0.033
# Style: 1.756, Content: 0.024
# Style: 1.605, Content: 0.014
# Style: 1.325, Content: 0.033
# Style: 1.505, Content: 0.029
# Style: 1.360, Content: 0.034
# Style: 1.755, Content: 0.021
# Style: 1.591, Content: 0.014
# Style: 1.334, Content: 0.032
# Style: 1.501, Content: 0.030
# Style: 1.357, Content: 0.033
# Style: 1.760, Content: 0.021
# Style: 1.581, Content: 0.014
# Style: 1.325, Content: 0.032
# Style: 1.504, Content: 0.029
# Style: 1.358, Content: 0.034
# Style: 1.746, Content: 0.021
# Style: 1.608, Content: 0.014
# Style: 1.319, Content: 0.030
# Style: 1.504, Content: 0.029
# Style: 1.365, Content: 0.034
# Style: 1.751, Content: 0.021
# Style: 1.584, Content: 0.015
# Style: 1.322, Content: 0.031
# Style: 1.504, Content: 0.029
# Style: 1.358, Content: 0.034
# Style: 1.740, Content: 0.021
# Style: 1.586, Content: 0.015
# Style: 1.323, Content: 0.031
# Style: 1.503, Content: 0.029
# Style: 1.368, Content: 0.033
# Style: 1.747, Content: 0.021
# Style: 1.584, Content: 0.016
# Style: 1.324, Content: 0.031
# Style: 1.509, Content: 0.029
# Style: 1.355, Content: 0.034
# Style: 1.739, Content: 0.021
# Style: 1.587, Content: 0.017
# Style: 1.333, Content: 0.032
# Style: 1.497, Content: 0.029
# Style: 1.353, Content: 0.034
# Style: 1.759, Content: 0.020
# Style: 1.578, Content: 0.021
# Style: 1.320, Content: 0.033
# Style: 1.499, Content: 0.029
# Style: 1.352, Content: 0.034
# Style: 1.738, Content: 0.021
# Style: 1.613, Content: 0.018
# Style: 1.323, Content: 0.032
# Style: 1.509, Content: 0.029
# Style: 1.350, Content: 0.033
# Style: 1.747, Content: 0.020
# Style: 1.581, Content: 0.019
# Style: 1.308, Content: 0.032
# Style: 1.484, Content: 0.029
# Style: 1.331, Content: 0.033
# Style: 1.734, Content: 0.022
# Style: 1.582, Content: 0.017
# Style: 1.309, Content: 0.033
# Style: 1.491, Content: 0.028
# Style: 1.350, Content: 0.033
# Style: 1.753, Content: 0.020
# Style: 1.574, Content: 0.020
# Style: 1.308, Content: 0.032
# Style: 1.489, Content: 0.029
# Style: 1.350, Content: 0.033
# Style: 1.736, Content: 0.020
# Style: 1.572, Content: 0.017
# Style: 1.308, Content: 0.032
# Style: 1.489, Content: 0.029
# Style: 1.331, Content: 0.034
# Style: 1.732, Content: 0.021
# Style: 1.581, Content: 0.018
# Style: 1.309, Content: 0.032
# Style: 1.487, Content: 0.030
# Style: 1.349, Content: 0.034
# Style: 1.733, Content: 0.022
# Style: 1.573, Content: 0.019
# Style: 1.312, Content: 0.031
# Style: 1.499, Content: 0.029
# Style: 1.338, Content: 0.034
# Style: 1.735, Content: 0.021
# Style: 1.586, Content: 0.018
# Style: 1.309, Content: 0.031
# Style: 1.487, Content: 0.031
# Style: 1.353, Content: 0.035
# Style: 1.741, Content: 0.022
# Style: 1.566, Content: 0.019
# Style: 1.303, Content: 0.031
# Style: 1.489, Content: 0.029
# Style: 1.335, Content: 0.035
# Style: 1.730, Content: 0.020
# Style: 1.574, Content: 0.017
# Style: 1.302, Content: 0.031
# Style: 1.476, Content: 0.029
# Style: 1.349, Content: 0.034
# Style: 1.727, Content: 0.021
# Style: 1.566, Content: 0.016
# Style: 1.302, Content: 0.031
# Style: 1.474, Content: 0.028
# Style: 1.336, Content: 0.033
# Style: 1.728, Content: 0.021
# Style: 1.563, Content: 0.016
# Style: 1.305, Content: 0.030
# Style: 1.475, Content: 0.029
# Style: 1.327, Content: 0.034
# Style: 1.723, Content: 0.021
# Style: 1.553, Content: 0.015
# Style: 1.299, Content: 0.031
# Style: 1.477, Content: 0.027
# Style: 1.319, Content: 0.033
# Style: 1.725, Content: 0.021
# Style: 1.557, Content: 0.016
# Style: 1.301, Content: 0.031
# Style: 1.471, Content: 0.028
# Style: 1.339, Content: 0.034
# Style: 1.721, Content: 0.021
# Style: 1.552, Content: 0.015
# Style: 1.303, Content: 0.031
# Style: 1.478, Content: 0.028
# Style: 1.332, Content: 0.033
# Style: 1.736, Content: 0.021
# Style: 1.580, Content: 0.016
# Style: 1.305, Content: 0.031
# Style: 1.478, Content: 0.030
# Style: 1.337, Content: 0.034
# Style: 1.727, Content: 0.022
# Style: 1.553, Content: 0.016
# Style: 1.300, Content: 0.031
# Style: 1.475, Content: 0.030
# Style: 1.340, Content: 0.034
# Style: 1.742, Content: 0.023
# Style: 1.552, Content: 0.019
# Style: 1.303, Content: 0.031
# Style: 1.476, Content: 0.031
# Style: 1.343, Content: 0.035
# Style: 1.723, Content: 0.022
# Style: 1.556, Content: 0.015
# Style: 1.296, Content: 0.031
# Style: 1.470, Content: 0.030
# Style: 1.337, Content: 0.034
# Style: 1.728, Content: 0.021
# Style: 1.551, Content: 0.016
# Style: 1.298, Content: 0.030
# Style: 1.467, Content: 0.030
# Style: 1.329, Content: 0.034
# Style: 1.716, Content: 0.021
# Style: 1.553, Content: 0.016
# Style: 1.290, Content: 0.030
# Style: 1.466, Content: 0.029
# Style: 1.332, Content: 0.033
# Style: 1.723, Content: 0.021
# Style: 1.555, Content: 0.016
# Style: 1.297, Content: 0.030
# Style: 1.462, Content: 0.029
# Style: 1.322, Content: 0.034
# Style: 1.716, Content: 0.021
# Style: 1.539, Content: 0.015
# Style: 1.290, Content: 0.031
# Style: 1.466, Content: 0.028
# Style: 1.329, Content: 0.033
# Style: 1.720, Content: 0.020
# Style: 1.548, Content: 0.015
# Style: 1.291, Content: 0.031
# Style: 1.453, Content: 0.029
# Style: 1.310, Content: 0.034
# Style: 1.707, Content: 0.021
# Style: 1.532, Content: 0.016
# Style: 1.284, Content: 0.031
# Style: 1.466, Content: 0.028
# Style: 1.332, Content: 0.034
# Style: 1.721, Content: 0.020
# Style: 1.556, Content: 0.015
# Style: 1.285, Content: 0.032
# Style: 1.448, Content: 0.029
# Style: 1.306, Content: 0.034
# Style: 1.704, Content: 0.022
# Style: 1.529, Content: 0.015
# Style: 1.280, Content: 0.032
# Style: 1.452, Content: 0.028
# Style: 1.325, Content: 0.033
# Style: 1.717, Content: 0.020
# Style: 1.536, Content: 0.014
# Style: 1.280, Content: 0.033
# Style: 1.452, Content: 0.029
# Style: 1.320, Content: 0.034
# Style: 1.711, Content: 0.022
# Style: 1.530, Content: 0.015
# Style: 1.281, Content: 0.032
# Style: 1.451, Content: 0.029
# Style: 1.312, Content: 0.033
# Style: 1.714, Content: 0.022
# Style: 1.536, Content: 0.014
# Style: 1.273, Content: 0.033
# Style: 1.447, Content: 0.029
# Style: 1.303, Content: 0.034
# Style: 1.713, Content: 0.023
# Style: 1.522, Content: 0.017
# Style: 1.278, Content: 0.031
# Style: 1.451, Content: 0.029
# Style: 1.314, Content: 0.035
# Style: 1.710, Content: 0.022
# Style: 1.535, Content: 0.015
# Style: 1.277, Content: 0.032
# Style: 1.449, Content: 0.029
# Style: 1.308, Content: 0.034
# Style: 1.738, Content: 0.022
# Style: 1.554, Content: 0.021
# Style: 1.284, Content: 0.031
# Style: 1.449, Content: 0.030
# Style: 1.308, Content: 0.035
# Style: 1.704, Content: 0.022
# Style: 1.533, Content: 0.017
# Style: 1.274, Content: 0.031
# Style: 1.448, Content: 0.029
# Style: 1.307, Content: 0.034
# Style: 1.712, Content: 0.021
# Style: 1.533, Content: 0.019
# Style: 1.275, Content: 0.031
# Style: 1.446, Content: 0.030
# Style: 1.302, Content: 0.035
# Style: 1.697, Content: 0.022
# Style: 1.534, Content: 0.018
# Style: 1.271, Content: 0.031
# Style: 1.447, Content: 0.031
# Style: 1.314, Content: 0.034
# Style: 1.712, Content: 0.020
# Style: 1.534, Content: 0.018
# Style: 1.272, Content: 0.032
# Style: 1.447, Content: 0.031
# Style: 1.297, Content: 0.035
# Style: 1.694, Content: 0.022
# Style: 1.529, Content: 0.018
# Style: 1.271, Content: 0.031
# Style: 1.444, Content: 0.029
# Style: 1.297, Content: 0.034
# Style: 1.713, Content: 0.020
# Style: 1.527, Content: 0.018
# Style: 1.265, Content: 0.032
# Style: 1.437, Content: 0.030
# Style: 1.298, Content: 0.035
# Style: 1.690, Content: 0.022
# Style: 1.528, Content: 0.016
# Style: 1.270, Content: 0.032
# Style: 1.438, Content: 0.030
# Style: 1.298, Content: 0.034
# Style: 1.706, Content: 0.020
# Style: 1.521, Content: 0.016
# Style: 1.262, Content: 0.032
# Style: 1.435, Content: 0.029
# Style: 1.295, Content: 0.034
# Style: 1.688, Content: 0.022
# Style: 1.526, Content: 0.015
# Style: 1.259, Content: 0.031
# Style: 1.429, Content: 0.029
# Style: 1.299, Content: 0.035
# Style: 1.699, Content: 0.021
# Style: 1.513, Content: 0.015
# Style: 1.258, Content: 0.031
# Style: 1.427, Content: 0.029
# Style: 1.286, Content: 0.034
# Style: 1.690, Content: 0.022
# Style: 1.513, Content: 0.014
# Style: 1.257, Content: 0.031
# Style: 1.424, Content: 0.030
# Style: 1.296, Content: 0.035
# Style: 1.704, Content: 0.021
# Style: 1.515, Content: 0.014
# Style: 1.258, Content: 0.031
# Style: 1.432, Content: 0.028
# Style: 1.297, Content: 0.035
# Style: 1.697, Content: 0.022
# Style: 1.511, Content: 0.014
# Style: 1.263, Content: 0.031
# Style: 1.428, Content: 0.029
# Style: 1.287, Content: 0.035
# Style: 1.705, Content: 0.021
# Style: 1.507, Content: 0.015
# Style: 1.255, Content: 0.030
# Style: 1.431, Content: 0.030
# Style: 1.287, Content: 0.035
# Style: 1.690, Content: 0.022
# Style: 1.519, Content: 0.015
# Style: 1.261, Content: 0.030
# Style: 1.422, Content: 0.030
# Style: 1.284, Content: 0.035
# Style: 1.700, Content: 0.021
# Style: 1.516, Content: 0.018
# Style: 1.254, Content: 0.031
# Style: 1.430, Content: 0.030
# Style: 1.289, Content: 0.036
# Style: 1.682, Content: 0.022
# Style: 1.520, Content: 0.015
# Style: 1.255, Content: 0.032
# Style: 1.426, Content: 0.030
# Style: 1.272, Content: 0.034
# Style: 1.695, Content: 0.021
# Style: 1.501, Content: 0.017
# Style: 1.249, Content: 0.032
# Style: 1.426, Content: 0.029
# Style: 1.296, Content: 0.035
# Style: 1.686, Content: 0.021
# Style: 1.513, Content: 0.014
# Style: 1.250, Content: 0.032
# Style: 1.422, Content: 0.029
# Style: 1.278, Content: 0.034
# Style: 1.691, Content: 0.021
# Style: 1.504, Content: 0.015
# Style: 1.245, Content: 0.031
# Style: 1.419, Content: 0.030
# Style: 1.274, Content: 0.035
# Style: 1.686, Content: 0.022
# Style: 1.524, Content: 0.014
# Style: 1.244, Content: 0.032
# Style: 1.419, Content: 0.029
# Style: 1.280, Content: 0.035
# Style: 1.687, Content: 0.023
# Style: 1.501, Content: 0.015
# Style: 1.249, Content: 0.031
# Style: 1.425, Content: 0.028
# Style: 1.275, Content: 0.035
# Style: 1.689, Content: 0.023
# Style: 1.498, Content: 0.015
# Style: 1.241, Content: 0.032
# Style: 1.415, Content: 0.028
# Style: 1.275, Content: 0.035
# Style: 1.691, Content: 0.022
# Style: 1.502, Content: 0.016
# Style: 1.251, Content: 0.031
# Style: 1.412, Content: 0.030
# Style: 1.267, Content: 0.035
# Style: 1.692, Content: 0.022
# Style: 1.500, Content: 0.016
# Style: 1.237, Content: 0.031
# Style: 1.417, Content: 0.028
# Style: 1.278, Content: 0.034
# Style: 1.689, Content: 0.022
# Style: 1.504, Content: 0.019
# Style: 1.255, Content: 0.031
# Style: 1.414, Content: 0.030
# Style: 1.276, Content: 0.036
# Style: 1.675, Content: 0.022
# Style: 1.497, Content: 0.020
# Style: 1.251, Content: 0.031
# Style: 1.424, Content: 0.031
# Style: 1.286, Content: 0.036
# Style: 1.699, Content: 0.020
# Style: 1.534, Content: 0.020
# Style: 1.245, Content: 0.032
# Style: 1.410, Content: 0.032
# Style: 1.268, Content: 0.037
# Style: 1.682, Content: 0.023
# Style: 1.529, Content: 0.020
# Style: 1.242, Content: 0.032
# Style: 1.412, Content: 0.031
# Style: 1.289, Content: 0.035
# Style: 1.693, Content: 0.021
# Style: 1.517, Content: 0.022
# Style: 1.234, Content: 0.031
# Style: 1.412, Content: 0.030
# Style: 1.266, Content: 0.035
# Style: 1.670, Content: 0.023
# Style: 1.506, Content: 0.016
# Style: 1.239, Content: 0.031
# Style: 1.400, Content: 0.030
# Style: 1.281, Content: 0.036
# Style: 1.686, Content: 0.021
# Style: 1.508, Content: 0.017
# Style: 1.235, Content: 0.030
# Style: 1.406, Content: 0.030
# Style: 1.265, Content: 0.036
# Style: 1.671, Content: 0.022
# Style: 1.499, Content: 0.015
# Style: 1.227, Content: 0.031
# Style: 1.406, Content: 0.029
# Style: 1.271, Content: 0.035
# Style: 1.683, Content: 0.021
# Style: 1.509, Content: 0.015
# Style: 1.233, Content: 0.031
# Style: 1.403, Content: 0.030
# Style: 1.271, Content: 0.036
# Style: 1.665, Content: 0.022
# Style: 1.498, Content: 0.016
# Style: 1.240, Content: 0.030
# Style: 1.398, Content: 0.030
# Style: 1.262, Content: 0.035
# Style: 1.682, Content: 0.021
# Style: 1.494, Content: 0.015
# Style: 1.232, Content: 0.031
# Style: 1.400, Content: 0.030
# Style: 1.266, Content: 0.036
# Style: 1.666, Content: 0.022
# Style: 1.489, Content: 0.014
# Style: 1.231, Content: 0.030
# Style: 1.392, Content: 0.029
# Style: 1.259, Content: 0.035
# Style: 1.683, Content: 0.021
# Style: 1.483, Content: 0.015
# Style: 1.223, Content: 0.030
# Style: 1.403, Content: 0.030
# Style: 1.261, Content: 0.037
# Style: 1.668, Content: 0.022
# Style: 1.505, Content: 0.014
# Style: 1.237, Content: 0.030
# Style: 1.396, Content: 0.030
# Style: 1.254, Content: 0.035
# Style: 1.679, Content: 0.022
# Style: 1.483, Content: 0.016
# Style: 1.219, Content: 0.031
# Style: 1.394, Content: 0.031
# Style: 1.267, Content: 0.036
# Style: 1.667, Content: 0.022
# Style: 1.496, Content: 0.014
# Style: 1.225, Content: 0.031
# Style: 1.390, Content: 0.030
# Style: 1.250, Content: 0.035
# Style: 1.669, Content: 0.022
# Style: 1.479, Content: 0.015
# Style: 1.220, Content: 0.030
# Style: 1.387, Content: 0.030
# Style: 1.252, Content: 0.036
# Style: 1.669, Content: 0.021
# Style: 1.485, Content: 0.014
# Style: 1.222, Content: 0.031
# Style: 1.389, Content: 0.030
# Style: 1.246, Content: 0.035
# Style: 1.671, Content: 0.022
# Style: 1.496, Content: 0.015
# Style: 1.220, Content: 0.031
# Style: 1.380, Content: 0.031
# Style: 1.263, Content: 0.037
# Style: 1.661, Content: 0.022
# Style: 1.484, Content: 0.014
# Style: 1.221, Content: 0.031
# Style: 1.379, Content: 0.030
# Style: 1.240, Content: 0.036
# Style: 1.663, Content: 0.023
# Style: 1.478, Content: 0.015
# Style: 1.218, Content: 0.031
# Style: 1.385, Content: 0.030
# Style: 1.247, Content: 0.035
# Style: 1.677, Content: 0.022
# Style: 1.479, Content: 0.015
# Style: 1.216, Content: 0.032
# Style: 1.393, Content: 0.029
# Style: 1.236, Content: 0.035
# Style: 1.669, Content: 0.024
# Style: 1.481, Content: 0.017
# Style: 1.219, Content: 0.031
# Style: 1.378, Content: 0.030
# Style: 1.252, Content: 0.036
# Style: 1.665, Content: 0.023
# Style: 1.480, Content: 0.016
# Style: 1.216, Content: 0.031
# Style: 1.388, Content: 0.030
# Style: 1.254, Content: 0.036
# Style: 1.686, Content: 0.023
# Style: 1.484, Content: 0.018
# Style: 1.227, Content: 0.030
# Style: 1.387, Content: 0.033
# Style: 1.255, Content: 0.038
# Style: 1.662, Content: 0.023
# Style: 1.480, Content: 0.017
# Style: 1.220, Content: 0.031
# Style: 1.396, Content: 0.030
# Style: 1.260, Content: 0.036
# Style: 1.688, Content: 0.020
# Style: 1.488, Content: 0.017
# Style: 1.220, Content: 0.031
# Style: 1.380, Content: 0.032
# Style: 1.258, Content: 0.037
# Style: 1.657, Content: 0.022
# Style: 1.485, Content: 0.015
# Style: 1.215, Content: 0.030
# Style: 1.379, Content: 0.030
# Style: 1.252, Content: 0.036
# Style: 1.678, Content: 0.021
# Style: 1.478, Content: 0.017
# Style: 1.213, Content: 0.031
# Style: 1.377, Content: 0.031
# Style: 1.247, Content: 0.036
# Style: 1.655, Content: 0.023
# Style: 1.476, Content: 0.014
# Style: 1.210, Content: 0.031
# Style: 1.380, Content: 0.030
# Style: 1.247, Content: 0.036
# Style: 1.671, Content: 0.020
# Style: 1.470, Content: 0.015
# Style: 1.208, Content: 0.031
# Style: 1.378, Content: 0.030
# Style: 1.243, Content: 0.036
# Style: 1.653, Content: 0.022
# Style: 1.475, Content: 0.014
# Style: 1.208, Content: 0.031
# Style: 1.382, Content: 0.030
# Style: 1.240, Content: 0.035
# Style: 1.669, Content: 0.021
# Style: 1.469, Content: 0.015
# Style: 1.205, Content: 0.030
# Style: 1.382, Content: 0.030
# Style: 1.233, Content: 0.037
# Style: 1.649, Content: 0.022
# Style: 1.473, Content: 0.014
# Style: 1.206, Content: 0.030
# Style: 1.364, Content: 0.030
# Style: 1.236, Content: 0.035
# Style: 1.663, Content: 0.021
# Style: 1.468, Content: 0.015
# Style: 1.201, Content: 0.030
# Style: 1.381, Content: 0.029
# Style: 1.243, Content: 0.037
# Style: 1.650, Content: 0.022
# Style: 1.476, Content: 0.014
# Style: 1.214, Content: 0.030
# Style: 1.367, Content: 0.030
# Style: 1.234, Content: 0.036
# Style: 1.664, Content: 0.021
# Style: 1.464, Content: 0.016
# Style: 1.206, Content: 0.031
# Style: 1.370, Content: 0.031
# Style: 1.235, Content: 0.037
# Style: 1.653, Content: 0.022
# Style: 1.476, Content: 0.014
# Style: 1.211, Content: 0.032
# Style: 1.375, Content: 0.030
# Style: 1.235, Content: 0.036
# Style: 1.666, Content: 0.021
# Style: 1.465, Content: 0.014
# Style: 1.208, Content: 0.031
# Style: 1.377, Content: 0.031
# Style: 1.233, Content: 0.036
# Style: 1.653, Content: 0.022
# Style: 1.471, Content: 0.013
# Style: 1.209, Content: 0.031
# Style: 1.362, Content: 0.031
# Style: 1.238, Content: 0.036
# Style: 1.661, Content: 0.022
# Style: 1.462, Content: 0.014
# Style: 1.201, Content: 0.031
# Style: 1.375, Content: 0.031
# Style: 1.223, Content: 0.037
# Style: 1.654, Content: 0.021
# Style: 1.474, Content: 0.013
# Style: 1.201, Content: 0.031
# Style: 1.360, Content: 0.030
# Style: 1.233, Content: 0.036
# Style: 1.659, Content: 0.023
# Style: 1.463, Content: 0.014
# Style: 1.197, Content: 0.031
# Style: 1.356, Content: 0.031
# Style: 1.233, Content: 0.037
# Style: 1.653, Content: 0.022
# Style: 1.466, Content: 0.014
# Style: 1.200, Content: 0.030
# Style: 1.366, Content: 0.030
# Style: 1.224, Content: 0.036
# Style: 1.659, Content: 0.021
# Style: 1.473, Content: 0.018
# Style: 1.209, Content: 0.030
# Style: 1.364, Content: 0.032
# Style: 1.242, Content: 0.037
# Style: 1.645, Content: 0.022
# Style: 1.473, Content: 0.019
# Style: 1.201, Content: 0.031
# Style: 1.377, Content: 0.032
# Style: 1.237, Content: 0.037
# Style: 1.660, Content: 0.021
# Style: 1.479, Content: 0.019
# Style: 1.202, Content: 0.031
# Style: 1.367, Content: 0.032
# Style: 1.235, Content: 0.037
# Style: 1.645, Content: 0.023
# Style: 1.476, Content: 0.018
# Style: 1.208, Content: 0.031
# Style: 1.371, Content: 0.031
# Style: 1.237, Content: 0.037
# Style: 1.660, Content: 0.020
# Style: 1.475, Content: 0.018
# Style: 1.199, Content: 0.031
# Style: 1.361, Content: 0.031
# Style: 1.226, Content: 0.037
# Style: 1.640, Content: 0.023
# Style: 1.467, Content: 0.015
# Style: 1.196, Content: 0.030
# Style: 1.358, Content: 0.031
# Style: 1.242, Content: 0.036
# Style: 1.651, Content: 0.021
# Style: 1.470, Content: 0.016
# Style: 1.195, Content: 0.031
# Style: 1.365, Content: 0.030
# Style: 1.225, Content: 0.037
# Style: 1.643, Content: 0.023
# Style: 1.459, Content: 0.015
# Style: 1.189, Content: 0.031
# Style: 1.353, Content: 0.031
# Style: 1.233, Content: 0.036
# Style: 1.649, Content: 0.022
# Style: 1.465, Content: 0.016
# Propagation iteration 1 done
# Propagation iteration 2 done
# Propagation iteration 3 done
# Propagation iteration 4 done
# Propagation iteration 5 done
# 最佳类别数：3, 轮廓系数：0.4800
# Optimizing at resoluton [168, 256]
# Style: 2.046, Content: 0.057
# Style: 1.996, Content: 0.069
# Style: 2.117, Content: 0.073
# Style: 1.919, Content: 0.065
# Style: 1.855, Content: 0.062
# Style: 1.937, Content: 0.063
# Style: 1.812, Content: 0.056
# Style: 1.723, Content: 0.053
# Style: 1.827, Content: 0.053
# Style: 1.718, Content: 0.053
# Style: 1.642, Content: 0.049
# Style: 1.741, Content: 0.051
# Style: 1.690, Content: 0.050
# Style: 1.572, Content: 0.050
# Style: 1.728, Content: 0.051
# Style: 1.621, Content: 0.054
# Style: 1.539, Content: 0.049
# Style: 1.687, Content: 0.050
# Style: 1.597, Content: 0.051
# Style: 1.502, Content: 0.048
# Style: 1.650, Content: 0.051
# Style: 1.563, Content: 0.053
# Style: 1.467, Content: 0.054
# Style: 1.633, Content: 0.050
# Style: 1.580, Content: 0.053
# Style: 1.454, Content: 0.051
# Style: 1.631, Content: 0.051
# Style: 1.534, Content: 0.049
# Style: 1.434, Content: 0.049
# Style: 1.605, Content: 0.048
# Style: 1.531, Content: 0.052
# Style: 1.408, Content: 0.049
# Style: 1.597, Content: 0.049
# Style: 1.532, Content: 0.048
# ...
# Style: 1.042, Content: 0.082
# Style: 1.116, Content: 0.078
# Style: 1.018, Content: 0.083
# Style: 1.176, Content: 0.080
# Style: 1.032, Content: 0.084
# Style: 1.122, Content: 0.079
# Style: 1.026, Content: 0.083
# Style: 1.165, Content: 0.081
# Style: 1.035, Content: 0.082
# Style: 1.111, Content: 0.080
# Style: 1.018, Content: 0.083
# Style: 1.169, Content: 0.080
# Style: 1.030, Content: 0.082
# Style: 1.116, Content: 0.080
# Style: 1.012, Content: 0.082
# Style: 1.165, Content: 0.080
# Style: 1.037, Content: 0.082
# Style: 1.112, Content: 0.079
# Style: 1.018, Content: 0.083
# Style: 1.167, Content: 0.081
# Style: 1.031, Content: 0.082
# Style: 1.112, Content: 0.079
# Style: 1.024, Content: 0.084
# Style: 1.160, Content: 0.081
# Style: 1.027, Content: 0.083
# Style: 1.110, Content: 0.080
# Style: 1.011, Content: 0.082
# Style: 1.157, Content: 0.081
# Style: 1.033, Content: 0.083
# Style: 1.113, Content: 0.079
# Style: 1.006, Content: 0.084
# Style: 1.149, Content: 0.082
# Style: 1.021, Content: 0.083
# Style: 1.100, Content: 0.079
# Style: 1.018, Content: 0.083
# Style: 1.155, Content: 0.080
# Style: 1.028, Content: 0.080
# Style: 1.110, Content: 0.079
# Style: 1.010, Content: 0.083
# Style: 1.151, Content: 0.083
# Style: 1.037, Content: 0.083
# Style: 1.097, Content: 0.079
# Style: 1.006, Content: 0.085
# Style: 1.151, Content: 0.082
# Style: 1.012, Content: 0.083
# Style: 1.109, Content: 0.078
# Style: 1.003, Content: 0.081
# Style: 1.148, Content: 0.081
# Style: 1.021, Content: 0.082
# Style: 1.099, Content: 0.079
# Style: 1.002, Content: 0.082
# Style: 1.145, Content: 0.081
# Style: 1.014, Content: 0.083
# Style: 1.100, Content: 0.079
# Style: 1.009, Content: 0.083
# Style: 1.145, Content: 0.081
# Style: 1.018, Content: 0.082
# Style: 1.100, Content: 0.078
# Style: 1.007, Content: 0.085
# Style: 1.145, Content: 0.081
# Style: 1.013, Content: 0.082
# Style: 1.101, Content: 0.078
# Style: 0.996, Content: 0.083
# Style: 1.148, Content: 0.082
# Style: 1.015, Content: 0.084
# Style: 1.097, Content: 0.080
# Style: 0.992, Content: 0.086
# Style: 1.144, Content: 0.080
# Style: 1.023, Content: 0.084
# Style: 1.103, Content: 0.079
# Style: 0.998, Content: 0.082
# Style: 1.146, Content: 0.082
# Style: 1.011, Content: 0.083
# Style: 1.095, Content: 0.079
# Style: 0.996, Content: 0.085
# Style: 1.137, Content: 0.081
# Style: 1.021, Content: 0.083
# Style: 1.092, Content: 0.079
# Style: 0.989, Content: 0.083
# Style: 1.153, Content: 0.083
# Style: 1.009, Content: 0.085
# Style: 1.084, Content: 0.081
# Style: 0.988, Content: 0.084
# Style: 1.140, Content: 0.082
# Style: 1.007, Content: 0.083
# Style: 1.082, Content: 0.080
# Style: 0.987, Content: 0.085
# Style: 1.135, Content: 0.082
# Style: 1.004, Content: 0.081
# Style: 1.083, Content: 0.080
# Style: 0.989, Content: 0.083
# Style: 1.138, Content: 0.081
# Style: 1.013, Content: 0.081
# Style: 1.093, Content: 0.079
# Style: 0.990, Content: 0.083
# Style: 1.134, Content: 0.082
# Style: 1.001, Content: 0.083
# Style: 1.080, Content: 0.080
# Style: 0.981, Content: 0.082
# Style: 1.132, Content: 0.081
# Style: 1.002, Content: 0.084
# Style: 1.075, Content: 0.082
# Style: 0.985, Content: 0.084
# Style: 1.141, Content: 0.082
# Style: 1.005, Content: 0.083
# Style: 1.075, Content: 0.080
# Style: 0.988, Content: 0.085
# Style: 1.130, Content: 0.080
# Style: 1.000, Content: 0.081
# Style: 1.075, Content: 0.080
# Style: 0.987, Content: 0.085
# Style: 1.125, Content: 0.081
# Style: 0.999, Content: 0.083
# Style: 1.080, Content: 0.081
# Style: 0.978, Content: 0.085
# Style: 1.130, Content: 0.082
# Style: 1.000, Content: 0.085
# Style: 1.080, Content: 0.080
# Style: 0.993, Content: 0.085
# Style: 1.121, Content: 0.083
# Style: 0.995, Content: 0.082
# Style: 1.080, Content: 0.079
# Style: 0.976, Content: 0.085
# Style: 1.115, Content: 0.081
# Style: 0.997, Content: 0.084
# Style: 1.074, Content: 0.080
# Style: 0.974, Content: 0.083
# Style: 1.130, Content: 0.081
# Style: 1.005, Content: 0.082
# Style: 1.076, Content: 0.079
# Style: 0.985, Content: 0.084
# Style: 1.138, Content: 0.081
# Style: 1.005, Content: 0.084
# Style: 1.070, Content: 0.079
# Style: 0.987, Content: 0.082
# Style: 1.127, Content: 0.083
# Style: 1.001, Content: 0.085
# Style: 1.075, Content: 0.081
# Style: 0.979, Content: 0.082
# Style: 1.117, Content: 0.080
# Style: 0.995, Content: 0.083
# Style: 1.076, Content: 0.079
# Style: 0.978, Content: 0.084
# Style: 1.120, Content: 0.082
# Style: 0.990, Content: 0.086
# Style: 1.059, Content: 0.080
# Style: 0.974, Content: 0.083
# Style: 1.109, Content: 0.083
# Style: 1.005, Content: 0.082
# Style: 1.067, Content: 0.080
# Style: 0.973, Content: 0.084
# Style: 1.115, Content: 0.081
# Style: 0.993, Content: 0.083
# Style: 1.065, Content: 0.081
# Style: 0.969, Content: 0.086
# Style: 1.117, Content: 0.081
# Style: 0.987, Content: 0.083
# Style: 1.068, Content: 0.081
# Style: 0.980, Content: 0.085
# Style: 1.109, Content: 0.082
# Style: 0.985, Content: 0.084
# Style: 1.064, Content: 0.080
# Style: 0.976, Content: 0.085
# Style: 1.117, Content: 0.082
# Style: 0.982, Content: 0.085
# Style: 1.071, Content: 0.080
# Style: 0.975, Content: 0.084
# Style: 1.107, Content: 0.082
# Style: 0.984, Content: 0.085
# Style: 1.060, Content: 0.080
# Style: 0.962, Content: 0.083
# Style: 1.104, Content: 0.084
# Style: 0.978, Content: 0.084
# Style: 1.064, Content: 0.080
# Style: 0.963, Content: 0.084
# Style: 1.114, Content: 0.084
# Style: 0.983, Content: 0.084
# Style: 1.062, Content: 0.081
# Style: 0.964, Content: 0.084
# Style: 1.107, Content: 0.083
# Style: 0.992, Content: 0.084
# Style: 1.058, Content: 0.081
# Style: 0.969, Content: 0.085
# Style: 1.114, Content: 0.083
# Style: 0.981, Content: 0.084
# Style: 1.053, Content: 0.079
# Style: 0.960, Content: 0.087
# Style: 1.107, Content: 0.081
# Style: 0.977, Content: 0.084
# Style: 1.064, Content: 0.080
# Style: 0.963, Content: 0.084
# Style: 1.103, Content: 0.082
# Style: 0.981, Content: 0.085
# Style: 1.074, Content: 0.080
# Style: 0.968, Content: 0.083
# Style: 1.112, Content: 0.081
# Style: 0.985, Content: 0.083
# Style: 1.054, Content: 0.081
# Style: 0.951, Content: 0.085
# Style: 1.104, Content: 0.083
# Style: 0.974, Content: 0.086
# Style: 1.060, Content: 0.079
# Style: 0.963, Content: 0.085
# Style: 1.101, Content: 0.082
# Style: 0.988, Content: 0.084
# Style: 1.059, Content: 0.081
# Style: 0.960, Content: 0.084
# Style: 1.113, Content: 0.083
# Style: 0.977, Content: 0.084
# Style: 1.052, Content: 0.079
# Style: 0.956, Content: 0.085
# Style: 1.103, Content: 0.081
# Style: 0.995, Content: 0.084
# Style: 1.056, Content: 0.081
# Style: 0.956, Content: 0.086
# Style: 1.102, Content: 0.081
# Style: 0.971, Content: 0.084
# Style: 1.049, Content: 0.081
# Style: 0.972, Content: 0.083
# Style: 1.104, Content: 0.083
# Style: 0.965, Content: 0.085
# Style: 1.047, Content: 0.081
# Style: 0.954, Content: 0.085
# Style: 1.116, Content: 0.083
# Style: 0.976, Content: 0.084
# Style: 1.047, Content: 0.080
# Style: 0.954, Content: 0.084
# Style: 1.101, Content: 0.082
# Style: 0.965, Content: 0.084
# Style: 1.051, Content: 0.082
# Style: 0.954, Content: 0.085
# Style: 1.107, Content: 0.082
# Style: 0.975, Content: 0.085
# Style: 1.051, Content: 0.081
# Style: 0.956, Content: 0.085
# Style: 1.093, Content: 0.082
# Style: 0.965, Content: 0.086
# Style: 1.050, Content: 0.080
# Style: 0.954, Content: 0.085
# Style: 1.096, Content: 0.084
# Style: 0.972, Content: 0.086
# Style: 1.047, Content: 0.079
# Style: 0.947, Content: 0.085
# Style: 1.102, Content: 0.082
# Style: 0.965, Content: 0.086
# Style: 1.036, Content: 0.081
# Style: 0.946, Content: 0.086
# Style: 1.088, Content: 0.083
# Style: 0.970, Content: 0.084
# Style: 1.040, Content: 0.081
# Style: 0.956, Content: 0.086
# Style: 1.092, Content: 0.083
# Style: 0.976, Content: 0.086
# Style: 1.043, Content: 0.080
# Style: 0.953, Content: 0.086
# Style: 1.091, Content: 0.082
# Style: 0.963, Content: 0.085
# Style: 1.048, Content: 0.080
# Style: 0.945, Content: 0.086
# Style: 1.088, Content: 0.083
# Style: 0.967, Content: 0.085
# Style: 1.038, Content: 0.080
# Style: 0.947, Content: 0.086
# Style: 1.084, Content: 0.084
# Style: 0.974, Content: 0.085
# Style: 1.043, Content: 0.079
# Style: 0.951, Content: 0.085
# Style: 1.088, Content: 0.083
# Style: 0.973, Content: 0.085
# Style: 1.033, Content: 0.080
# Style: 0.956, Content: 0.085
# Style: 1.091, Content: 0.083
# Style: 0.973, Content: 0.085
# Style: 1.047, Content: 0.080
# Style: 0.954, Content: 0.084
# Style: 1.089, Content: 0.083
# Style: 0.963, Content: 0.086
# Style: 1.038, Content: 0.079
# Style: 0.947, Content: 0.086
# Style: 1.082, Content: 0.083
# Style: 0.951, Content: 0.087
# Style: 1.034, Content: 0.081
# Style: 0.953, Content: 0.086
# Style: 1.084, Content: 0.082
# Style: 0.963, Content: 0.085
# Style: 1.030, Content: 0.081
# Style: 0.955, Content: 0.085
# Style: 1.086, Content: 0.082
# Style: 0.963, Content: 0.084
# Style: 1.030, Content: 0.081
# Style: 0.942, Content: 0.085
# Style: 1.089, Content: 0.084
# Style: 0.963, Content: 0.085
# Style: 1.031, Content: 0.081
# Style: 0.941, Content: 0.084
# Style: 1.083, Content: 0.082
# Style: 0.956, Content: 0.086
# Style: 1.035, Content: 0.081
# Style: 0.944, Content: 0.086
# Style: 1.084, Content: 0.084
# Style: 0.954, Content: 0.086
# Style: 1.026, Content: 0.081
# Style: 0.935, Content: 0.084
# Style: 1.074, Content: 0.084
# Style: 0.954, Content: 0.086
# Style: 1.036, Content: 0.081
# Style: 0.930, Content: 0.086
# Style: 1.086, Content: 0.082
# Style: 0.953, Content: 0.086
# Style: 1.039, Content: 0.080
# Style: 0.940, Content: 0.086
# Style: 1.078, Content: 0.084
# Style: 0.954, Content: 0.086
# Style: 1.026, Content: 0.081
# Style: 0.943, Content: 0.085
# Style: 1.083, Content: 0.084
# Style: 0.961, Content: 0.085
# Style: 1.035, Content: 0.080
# Style: 0.932, Content: 0.085
# Style: 1.073, Content: 0.084
# Style: 0.962, Content: 0.085
# Style: 1.023, Content: 0.080
# Style: 0.932, Content: 0.086
# Style: 1.074, Content: 0.085
# Style: 0.956, Content: 0.085
# Style: 1.026, Content: 0.081
# Style: 0.935, Content: 0.085
# Style: 1.079, Content: 0.083
# Style: 0.956, Content: 0.086
# Style: 1.033, Content: 0.080
# Style: 0.927, Content: 0.086
# Style: 1.072, Content: 0.084
# Style: 0.959, Content: 0.085
# Style: 1.020, Content: 0.082
# Style: 0.935, Content: 0.086
# Style: 1.073, Content: 0.082
# Style: 0.959, Content: 0.084
# Style: 1.030, Content: 0.080
# Style: 0.934, Content: 0.084
# Style: 1.067, Content: 0.082
# Style: 0.955, Content: 0.084
# Style: 1.024, Content: 0.082
# Style: 0.931, Content: 0.088
# Style: 1.063, Content: 0.083
# Style: 0.956, Content: 0.086
# Style: 1.026, Content: 0.081
# Style: 0.939, Content: 0.087
# Style: 1.081, Content: 0.083
# Style: 0.951, Content: 0.085
# Style: 1.023, Content: 0.081
# Style: 0.937, Content: 0.085
# Style: 1.071, Content: 0.083
# Style: 0.949, Content: 0.085
# Style: 1.031, Content: 0.081
# Style: 0.927, Content: 0.086
# Style: 1.068, Content: 0.084
# Style: 0.945, Content: 0.087
# Style: 1.032, Content: 0.078
# Style: 0.927, Content: 0.089
# Style: 1.073, Content: 0.082
# Style: 0.946, Content: 0.087
# Style: 1.018, Content: 0.079
# Style: 0.922, Content: 0.086
# Style: 1.072, Content: 0.084
# Style: 0.948, Content: 0.084
# Style: 1.018, Content: 0.082
# Style: 0.956, Content: 0.086
# Style: 1.075, Content: 0.082
# Style: 0.950, Content: 0.085
# Style: 1.021, Content: 0.081
# Style: 0.923, Content: 0.086
# Style: 1.078, Content: 0.084
# Style: 0.961, Content: 0.085
# Style: 1.021, Content: 0.081
# Style: 0.936, Content: 0.085
# Style: 1.076, Content: 0.083
# Style: 0.949, Content: 0.085
# Style: 1.023, Content: 0.081
# Style: 0.928, Content: 0.085
# Style: 1.073, Content: 0.084
# Style: 0.946, Content: 0.085
# Style: 1.022, Content: 0.080
# Style: 0.941, Content: 0.087
# Style: 1.073, Content: 0.082
# Style: 0.939, Content: 0.088
# Style: 1.019, Content: 0.080
# Style: 0.929, Content: 0.086
# Style: 1.071, Content: 0.084
# Style: 0.944, Content: 0.087
# Style: 1.022, Content: 0.082
# Style: 0.932, Content: 0.085
# Style: 1.072, Content: 0.082
# Style: 0.941, Content: 0.087
# Style: 1.017, Content: 0.081
# Style: 0.927, Content: 0.087
# Style: 1.065, Content: 0.083
# Style: 0.950, Content: 0.086
# Style: 1.014, Content: 0.079
# Style: 0.933, Content: 0.085
# Style: 1.064, Content: 0.082
# Style: 0.943, Content: 0.084
# Style: 1.013, Content: 0.081
# Style: 0.925, Content: 0.086
# Style: 1.063, Content: 0.084
# Style: 0.955, Content: 0.084
# Style: 1.017, Content: 0.080
# Style: 0.930, Content: 0.086
# Style: 1.063, Content: 0.083
# Style: 0.949, Content: 0.086
# Style: 1.008, Content: 0.080
# Style: 0.920, Content: 0.086
# Style: 1.063, Content: 0.084
# Style: 0.948, Content: 0.085
# Style: 1.020, Content: 0.080
# Style: 0.916, Content: 0.086
# Style: 1.064, Content: 0.083
# Style: 0.937, Content: 0.085
# Style: 1.009, Content: 0.081
# Style: 0.919, Content: 0.088
# Style: 1.061, Content: 0.083
# Style: 0.939, Content: 0.086
# Style: 1.006, Content: 0.082
# Style: 0.918, Content: 0.085
# Style: 1.066, Content: 0.084
# Style: 0.936, Content: 0.086
# Style: 1.008, Content: 0.080
# Style: 0.921, Content: 0.085
# Style: 1.064, Content: 0.086
# Style: 0.935, Content: 0.085
# Style: 1.007, Content: 0.081
# Style: 0.909, Content: 0.087
# Style: 1.064, Content: 0.084
# Style: 0.943, Content: 0.085
# Style: 1.005, Content: 0.081
# Style: 0.920, Content: 0.085
# Style: 1.057, Content: 0.083
# Style: 0.929, Content: 0.087
# Style: 1.013, Content: 0.080
# Style: 0.914, Content: 0.089
# Style: 1.076, Content: 0.083
# Style: 0.940, Content: 0.085
# Style: 1.006, Content: 0.080
# Style: 0.917, Content: 0.085
# Style: 1.057, Content: 0.083
# Style: 0.950, Content: 0.084
# Style: 1.006, Content: 0.080
# Style: 0.918, Content: 0.084
# Style: 1.050, Content: 0.082
# Style: 0.929, Content: 0.086
# Style: 1.002, Content: 0.081
# Style: 0.913, Content: 0.086
# Style: 1.052, Content: 0.085
# Style: 0.928, Content: 0.086
# Style: 1.007, Content: 0.081
# Style: 0.911, Content: 0.086
# Style: 1.059, Content: 0.084
# Style: 0.928, Content: 0.087
# Style: 1.008, Content: 0.080
# Style: 0.919, Content: 0.087
# Style: 1.055, Content: 0.085
# Style: 0.927, Content: 0.087
# Style: 1.007, Content: 0.081
# Style: 0.925, Content: 0.087
# Style: 1.050, Content: 0.083
# Style: 0.935, Content: 0.087
# Style: 1.008, Content: 0.081
# Style: 0.910, Content: 0.088
# Style: 1.053, Content: 0.084
# Style: 0.936, Content: 0.085
# Style: 0.999, Content: 0.081
# Style: 0.920, Content: 0.087
# Style: 1.063, Content: 0.083
# Style: 0.936, Content: 0.085
# Style: 1.005, Content: 0.082
# Style: 0.924, Content: 0.088
# Style: 1.057, Content: 0.082
# Style: 0.932, Content: 0.085
# Style: 1.008, Content: 0.080
# Style: 0.915, Content: 0.087
# Style: 1.053, Content: 0.083
# Style: 0.935, Content: 0.085
# Style: 0.997, Content: 0.081
# Style: 0.909, Content: 0.087
# Style: 1.046, Content: 0.083
# Style: 0.927, Content: 0.088
# Style: 1.003, Content: 0.082
# Style: 0.911, Content: 0.085
# Style: 1.056, Content: 0.084
# Style: 0.926, Content: 0.086
# Style: 0.997, Content: 0.082
# Style: 0.905, Content: 0.088
# Style: 1.043, Content: 0.085
# Style: 0.938, Content: 0.086
# Style: 1.000, Content: 0.081
# Style: 0.910, Content: 0.087
# Style: 1.051, Content: 0.085
# Style: 0.924, Content: 0.084
# Style: 1.001, Content: 0.080
# Style: 0.910, Content: 0.087
# Style: 1.049, Content: 0.084
# Style: 0.929, Content: 0.088
# Style: 0.996, Content: 0.080
# Style: 0.903, Content: 0.088
# Style: 1.049, Content: 0.083
# Style: 0.931, Content: 0.087
# Style: 0.994, Content: 0.082
# Style: 0.914, Content: 0.087
# Style: 1.049, Content: 0.084
# Style: 0.929, Content: 0.086
# Style: 0.997, Content: 0.081
# Style: 0.924, Content: 0.088
# Style: 1.050, Content: 0.085
# Style: 0.927, Content: 0.085
# Style: 0.998, Content: 0.083
# Style: 0.917, Content: 0.086
# Style: 1.047, Content: 0.084
# Style: 0.934, Content: 0.084
# Style: 1.000, Content: 0.081
# Style: 0.904, Content: 0.086
# Style: 1.055, Content: 0.084
# Style: 0.929, Content: 0.086
# Style: 1.002, Content: 0.081
# Style: 0.905, Content: 0.086
# Style: 1.056, Content: 0.083
# Style: 0.923, Content: 0.086
# Style: 0.987, Content: 0.081
# Style: 0.904, Content: 0.087
# Style: 1.035, Content: 0.085
# Style: 0.926, Content: 0.085
# Style: 1.004, Content: 0.081
# Style: 0.906, Content: 0.087
# Style: 1.050, Content: 0.085
# Style: 0.926, Content: 0.088
# Style: 1.005, Content: 0.080
# Style: 0.898, Content: 0.086
# Style: 1.041, Content: 0.083
# Style: 0.934, Content: 0.086
# Style: 0.993, Content: 0.081
# Style: 0.907, Content: 0.088
# Style: 1.044, Content: 0.084
# Style: 0.923, Content: 0.086
# Style: 0.993, Content: 0.083
# Style: 0.915, Content: 0.087
# Style: 1.043, Content: 0.085
# Style: 0.925, Content: 0.087
# Style: 1.003, Content: 0.082
# Style: 0.907, Content: 0.087
# Style: 1.039, Content: 0.083
# Style: 0.920, Content: 0.086
# Style: 0.993, Content: 0.081
# Style: 0.906, Content: 0.087
# Done in 427.841s
